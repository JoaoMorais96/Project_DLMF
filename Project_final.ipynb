# %% [markdown]
# # Deep Learning Methods For Finance

# %% [markdown]
# The objective of this work is to naively implement a simple recurrent neural network to solve a index prediction task. The index in question (aka the one we choose) is the SSMI.
#
# As was advised in class, we did not start with a random model, but with a simple model frame we obtained from: https://towardsdatascience.com/predicting-stock-prices-using-a-keras-lstm-model-4225457f0233 (its hard to find an architecture who does not include dropout layers from the beginning) and https://www.kaggle.com/code/ozkanozturk/stock-price-prediction-by-simple-rnn-and-lstm. But this models took way to long and we wanted to just experiment a lot of options in the beginning, so we opted with a very simple one layer model (which is also used here https://towardsdatascience.com/a-practical-guide-to-rnn-and-lstm-in-keras-980f176271bc).
#
# The performance of this simple RNN will be compared against a model containing an LSTM layer. For each of these, there will be 9 different models who vary in epoch

# %% [markdown]
# ## The problem
#
# The problem is to predict the price of the SSMI index

# %% [markdown]
# ## Loading the data

# %% [markdown]
# We will start by downloading the data from Kaggle:

# %%
import time
start_time = time.time()

# %%
import os
import pandas as pd
import warnings

# %%
df_project = pd.read_csv("indexProcessed.csv")
df_project['Close']=df_project['CloseUSD']
df_project.drop(['CloseUSD'], axis=1, inplace=True)
df_project = df_project.loc[df_project['Index'] == 'SSMI']
df_project.drop(['Index'], axis=1, inplace=True)
df = df_project.copy()
df.reset_index(inplace=True)
df.drop(['index'], axis=1, inplace=True)
df.head(5)
# Out:
#          Date         Open         High          Low        Close  \
# 0  1990-11-09  1378.900024  1389.000000  1375.300049  1539.680973
# 1  1990-11-12  1388.099976  1408.099976  1388.099976  1562.325000
# 2  1990-11-13  1412.199951  1429.400024  1411.400024  1570.871946
# 3  1990-11-14  1413.599976  1413.599976  1402.099976  1565.433054
# 4  1990-11-15  1410.599976  1416.699951  1405.099976  1560.326946
#
#      Adj Close  Volume
# 0  1387.099976     0.0
# 1  1407.500000     0.0
# 2  1415.199951     0.0
# 3  1410.300049     0.0
# 4  1405.699951     0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7671 entries, 0 to 7670
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       7671 non-null   object
#  1   Open       7671 non-null   float64
#  2   High       7671 non-null   float64
#  3   Low        7671 non-null   float64
#  4   Close      7671 non-null   float64
#  5   Adj Close  7671 non-null   float64
#  6   Volume     7671 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 419.6+ KB

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   7671.000000   7671.000000   7671.000000   7671.000000   7671.000000
# mean    6410.012762   6448.342905   6369.483406   7114.803716   6409.733078
# std     2441.470852   2451.869095   2429.404551   2709.188152   2440.710047
# min     1288.699951   1296.599976   1279.000000   1429.235973   1287.599976
# 25%     5087.549805   5140.919921   5030.660157   5641.686108   5082.600098
# 50%     6647.520020   6686.899902   6607.850098   7380.501109   6649.100098
# 75%     8280.505371   8319.204590   8230.109863   9191.049858   8280.225097
# max    11345.400390  11443.969730  11326.750000  12683.026933  11426.150390
#
#              Volume
# count  7.671000e+03
# mean   3.646631e+07
# std    3.656943e+07
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    4.003240e+07
# 75%    5.785615e+07
# max    3.467677e+08

# %% [markdown]
# ## Data preprocessing

# %%
import numpy as np
import tensorflow as tf

# Set random seed for numpy:
np.random.seed(42)

# Set random seed for tensorFlow
tf.random.set_seed(24)

# %% [markdown]
# Let's now start by converting the `Date` variable to datetime:

# %%
df["Date"] = pd.to_datetime(df["Date"])

display(df.dtypes)
display(df[["Date"]].sample(5))
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object
#            Date
# 6456 2016-07-13
# 3333 2004-02-18
# 5728 2013-08-15
# 5391 2012-04-05
# 1731 1997-10-02

# %% [markdown]
# We can extract the year, month and day from the original `Date` variable:

# %%
df["Year"] = df["Date"].apply(lambda x : str(x)[:4])
df["Month"] = df["Date"].apply(lambda x : str(x)[5:7])
df["Day"] = df["Date"].apply(lambda x : str(x)[8:10])

df.sample(3)
# Out:
#            Date         Open         High          Low        Close  \
# 411  1992-07-07  1864.900024  1868.800049  1850.300049  2060.825973
# 5076 2011-01-11  6454.390137  6542.640137  6451.109863  7253.672227
# 2757 2001-10-30  6053.200195  6075.600098  5976.399902  6668.880000
#
#         Adj Close      Volume  Year Month Day
# 411   1856.599976         0.0  1992    07  07
# 5076  6534.839844  49082600.0  2011    01  11
# 2757  6008.000000         0.0  2001    10  30

# %%
df.set_index("Date", inplace=True)
df.sample(5)
# Out:
#                    Open         High          Low         Close    Adj Close  \
# Date
# 2015-04-21  9317.059570  9357.419922  9299.429688  10322.366954  9299.429688
# 2017-02-14  8459.099609  8461.509766  8420.250000   9353.026934  8426.150391
# 1998-06-11  7651.600098  7651.899902  7489.600098   8323.223891  7498.399902
# 2006-07-17  7504.799805  7529.799805  7428.100098   8326.442784  7501.299805
# 1993-08-18  2464.500000  2489.699951  2463.600098   2760.791946  2487.199951
#
#                 Volume  Year Month Day
# Date
# 2015-04-21  57290400.0  2015    04  21
# 2017-02-14  52930200.0  2017    02  14
# 1998-06-11         0.0  1998    06  11
# 2006-07-17  63444400.0  2006    07  17
# 1993-08-18         0.0  1993    08  18

# %% [markdown]
# ### Splitting the data

# %%
# Imports 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(9,4))
plt.plot(df["Open"], color="lightblue")
plt.title("Open stock prices")
plt.show()

# %% [markdown]
# How many days of data do we have in our dataset?

# %%
len(df)
# Out:
# 7671

# %% [markdown]
# Let's try to predict the stock prices for the next 90 days.

# %%
open_prices = df[["Open"]].copy()
open_prices
# Out:
#                     Open
# Date
# 1990-11-09   1378.900024
# 1990-11-12   1388.099976
# 1990-11-13   1412.199951
# 1990-11-14   1413.599976
# 1990-11-15   1410.599976
# ...                  ...
# 2021-05-20  11091.320310
# 2021-05-21  11205.809570
# 2021-05-26  11325.419920
# 2021-05-27  11341.190430
# 2021-05-28  11345.400390
#
# [7671 rows x 1 columns]

# %%
open_prices.shape
# Out:
# (7671, 1)

# %% [markdown]
# Let's split the data into training, validation and test sets:
# - Training: all the data except the last 270 days (roughly 9 months)
# - Validation: 90 days right after the training set ends
# - Test: 270 days after the testing ends

# %%
split_time = len(df)-270 

train = open_prices[:split_time]
test = open_prices[split_time:]

validation_split_time = 90
val = train[-validation_split_time:]
train = train[:-validation_split_time]

print(f"Shape of train data: {train.shape}")
print(f"Shape of val data: {val.shape}")
print(f"Shape of test data: {test.shape}")
# Out:
# Shape of train data: (7311, 1)
# Shape of val data: (90, 1)
# Shape of test data: (270, 1)

# %%
plt.figure(figsize=(9,4))
plt.plot(train, color="lightblue")
plt.plot(val, color="lightgreen")
plt.plot(test, color="yellow")
plt.title("Open stock prices - train, val and test")
plt.show()

# %% [markdown]
# ### Standardize the data

# %%
# Imports:
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

train = scaler.fit_transform(train)
val = scaler.transform(val)
test = scaler.transform(test)

# %%
print(f"Shape of train: {train.shape}")
print(f"Shape of val: {val.shape}")
print(f"Shape of test: {test.shape}")
# Out:
# Shape of train: (7311, 1)
# Shape of val: (90, 1)
# Shape of test: (270, 1)

# %% [markdown]
# ### Prepare data for training

# %%
# Imports:

from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
timesteps = 30  # number of time steps to look back
batch_size = 32  # number of samples per batch

train_generator = TimeseriesGenerator(train, train, length=timesteps, batch_size=batch_size)
val_generator = TimeseriesGenerator(val, val, length=timesteps, batch_size=batch_size)
test_generator = TimeseriesGenerator(test, test, length=timesteps, batch_size=batch_size)

# %% [markdown]
# ## Training And Evaluating The Models

# %% [markdown]
# ### Simple RNN

# %% [markdown]
# #### Test 1

# %%
# Shared attributes:
loss_function = 'mse'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 50

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import SimpleRNN, Dense

rnn_model = Sequential()
rnn_model.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model.add(Dense(1))

rnn_model.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model.summary()

history_rnn_model = rnn_model.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 1, 128)            16640
#
#  dense (Dense)               (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\2091261247.py:12: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model = rnn_model.fit_generator(
# Epoch 1/50
# 228/228 [==============================] - 3s 7ms/step - loss: 0.0051 - mae: 0.0414 - val_loss: 0.0110 - val_mae: 0.0790
# Epoch 2/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0013 - mae: 0.0258 - val_loss: 0.0106 - val_mae: 0.0872
# Epoch 3/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0013 - mae: 0.0263 - val_loss: 0.0126 - val_mae: 0.0798
# Epoch 4/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0107 - val_mae: 0.0826
# Epoch 5/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 0.0107 - val_mae: 0.0813
# Epoch 6/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0105 - val_mae: 0.0811
# Epoch 7/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4395e-04 - mae: 0.0211 - val_loss: 0.0111 - val_mae: 0.0912
# Epoch 8/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0108 - val_mae: 0.0807
# Epoch 9/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0246 - val_loss: 0.0122 - val_mae: 0.0793
# Epoch 10/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0241 - val_loss: 0.0114 - val_mae: 0.0798
# Epoch 11/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0013 - mae: 0.0259 - val_loss: 0.0129 - val_mae: 0.0807
# Epoch 12/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0230 - val_loss: 0.0117 - val_mae: 0.0814
# Epoch 13/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0222 - val_loss: 0.0118 - val_mae: 0.0789
# Epoch 14/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4020e-04 - mae: 0.0216 - val_loss: 0.0131 - val_mae: 0.0800
# Epoch 15/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0240 - val_loss: 0.0108 - val_mae: 0.0890
# Epoch 16/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 0.0148 - val_mae: 0.0832
# Epoch 17/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.7744e-04 - mae: 0.0223 - val_loss: 0.0108 - val_mae: 0.0829
# Epoch 18/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6586e-04 - mae: 0.0222 - val_loss: 0.0113 - val_mae: 0.0810
# Epoch 19/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0145 - val_mae: 0.0822
# Epoch 20/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0233 - val_loss: 0.0127 - val_mae: 0.0797
# Epoch 21/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 0.0139 - val_mae: 0.0809
# Epoch 22/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0233 - val_loss: 0.0106 - val_mae: 0.0823
# Epoch 23/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0125 - val_mae: 0.0794
# Epoch 24/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.1480e-04 - mae: 0.0214 - val_loss: 0.0112 - val_mae: 0.0799
# Epoch 25/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6349e-04 - mae: 0.0218 - val_loss: 0.0151 - val_mae: 0.0842
# Epoch 26/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 0.0134 - val_mae: 0.0802
# Epoch 27/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5896e-04 - mae: 0.0220 - val_loss: 0.0123 - val_mae: 0.0790
# Epoch 28/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0224 - val_loss: 0.0113 - val_mae: 0.0811
# Epoch 29/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0131 - val_mae: 0.0796
# Epoch 30/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4582e-04 - mae: 0.0217 - val_loss: 0.0127 - val_mae: 0.0794
# Epoch 31/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5554e-04 - mae: 0.0217 - val_loss: 0.0145 - val_mae: 0.0822
# Epoch 32/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6291e-04 - mae: 0.0221 - val_loss: 0.0105 - val_mae: 0.0806
# Epoch 33/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.7268e-04 - mae: 0.0221 - val_loss: 0.0139 - val_mae: 0.0809
# Epoch 34/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0227 - val_loss: 0.0106 - val_mae: 0.0818
# Epoch 35/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0224 - val_loss: 0.0108 - val_mae: 0.0810
# Epoch 36/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0106 - val_mae: 0.0853
# Epoch 37/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6406e-04 - mae: 0.0221 - val_loss: 0.0110 - val_mae: 0.0802
# Epoch 38/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.7358e-04 - mae: 0.0220 - val_loss: 0.0162 - val_mae: 0.0876
# Epoch 39/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3823e-04 - mae: 0.0219 - val_loss: 0.0146 - val_mae: 0.0825
# Epoch 40/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 0.0115 - val_mae: 0.0791
# Epoch 41/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3441e-04 - mae: 0.0215 - val_loss: 0.0102 - val_mae: 0.0843
# Epoch 42/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.1286e-04 - mae: 0.0215 - val_loss: 0.0111 - val_mae: 0.0814
# Epoch 43/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.2307e-04 - mae: 0.0214 - val_loss: 0.0120 - val_mae: 0.0786
# Epoch 44/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4113e-04 - mae: 0.0217 - val_loss: 0.0126 - val_mae: 0.0790
# Epoch 45/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5312e-04 - mae: 0.0218 - val_loss: 0.0112 - val_mae: 0.0803
# Epoch 46/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.7237e-04 - mae: 0.0218 - val_loss: 0.0107 - val_mae: 0.0819
# Epoch 47/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0105 - val_mae: 0.0808
# Epoch 48/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9750e-04 - mae: 0.0225 - val_loss: 0.0110 - val_mae: 0.0808
# Epoch 49/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.0832e-04 - mae: 0.0214 - val_loss: 0.0104 - val_mae: 0.0828
# Epoch 50/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.0545e-04 - mae: 0.0213 - val_loss: 0.0115 - val_mae: 0.0792

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
def evaluate_model(model, model_name, train_gen, val_gen, test_gen, verbose=False):
    """Utility function that prints loss and MAE scores of a given model. Returns the results in a dataframe."""
    if verbose:
        print(f"Evaluation of {model_name}:")
    
    train_loss, train_mae = model.evaluate_generator(train_gen)
    val_loss, val_mae = model.evaluate_generator(val_gen)
    test_loss, test_mae = model.evaluate_generator(test_gen)
    
    if verbose:
        print(f"\nTest loss: {round(test_loss, 4)} \t | \ttest mae: {round(test_mae, 4)}")
        print(f"Val loss: {round(val_loss, 4)} \t | \tval mae: {round(val_mae, 4)}")
        print(f"Train loss: {round(train_loss, 4)} \t | \ttrain mae: {round(train_mae, 4)}")
        
    return pd.DataFrame.from_dict(
        [
            {
                "model_name": model_name,
                "test_loss": round(test_loss, 4),
                "test_mae": round(test_mae, 4),
                "val_loss": round(val_loss, 4),
                "val_mae": round(val_mae, 4),
                "train_loss": round(train_loss, 4),
                "train_mae": round(train_mae, 4)
            }
        ]
    )

# %%
results_rnn = evaluate_model(
    rnn_model,
    "RNN_MODEL1",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn
# Out:
# Evaluation of RNN_MODEL1:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0011 	 | 	test mae: 0.0262
# Val loss: 0.0115 	 | 	val mae: 0.0792
# Train loss: 0.0008 	 | 	train mae: 0.0192
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL1     0.0011    0.0262    0.0115   0.0792      0.0008     0.0192

# %%
train_preds = rnn_model.predict(train)
val_preds = rnn_model.predict(val)
test_preds = rnn_model.predict(test)

print(f"Shape of train_preds: {train_preds.shape}")
print(f"Shape of val_preds: {val_preds.shape}")
print(f"Shape of test_preds: {test_preds.shape}")
# Out:
# 229/229 [==============================] - 0s 999us/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %%
# The batch returns 2 arrays: features and targets
batch = train_generator[0]

lookback = len(batch[0][0])
num_days_being_predicted = len(batch[1][0])

print(f"The batch returns {len(batch)} arrays, corresponding to the X (features) and y (targets).")
print(f"The input sequences have length = {lookback}, meaning that our lookback is {lookback} days.")
print(f"Our target array has length = {num_days_being_predicted}, meaning that we are using the past {lookback} days to predict the next {num_days_being_predicted} day(s).")
# Out:
# The batch returns 2 arrays, corresponding to the X (features) and y (targets).
# The input sequences have length = 30, meaning that our lookback is 30 days.
# Our target array has length = 1, meaning that we are using the past 30 days to predict the next 1 day(s).

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
def plot_predictions(data_dict, indexes_dict, title, vars_to_plot=["train_preds", "val_preds", "test_preds", "train", "val", "test"]):
    # Note: this function assumes that data_d contains the info regarding true labels for train, val and test,
    # as well as predictions for train, val and test.
    color_code = {
        "train": "lightblue",
        "val": "lightgreen",
        "test": "yellow",
        "train_preds": "darkblue",
        "val_preds": "darkgreen",
        "test_preds": "orange"
    }
    
    plt.figure(figsize=(12,4))
    
    for col in vars_to_plot:
        plt.plot(indexes_dict[col], data_dict[col], color=color_code[col])
        
    
    plt.title(title)
    plt.show()

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds.ravel(), "val_preds": val_preds.ravel(), "test_preds": test_preds.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Test 2

# %%
# Shared attributes:
loss_function = 'mse'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 20

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
rnn_model2 = Sequential()
rnn_model2.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model2.add(Dense(1))

rnn_model2.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model2.summary()

history_rnn_model2 = rnn_model2.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)

rnn_model2.save('rnn_model2.h5')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 1, 128)            16640
#
#  dense_1 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1617963809.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model2 = rnn_model2.fit_generator(
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0090 - mae: 0.0481 - val_loss: 0.0114 - val_mae: 0.0824
# Epoch 2/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0015 - mae: 0.0275 - val_loss: 0.0127 - val_mae: 0.1003
# Epoch 3/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0013 - mae: 0.0254 - val_loss: 0.0102 - val_mae: 0.0848
# Epoch 4/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0012 - mae: 0.0239 - val_loss: 0.0119 - val_mae: 0.0793
# Epoch 5/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0257 - val_loss: 0.0119 - val_mae: 0.0797
# Epoch 6/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0250 - val_loss: 0.0124 - val_mae: 0.0794
# Epoch 7/20
# 228/228 [==============================] - 2s 7ms/step - loss: 9.8007e-04 - mae: 0.0224 - val_loss: 0.0104 - val_mae: 0.0826
# Epoch 8/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0228 - val_loss: 0.0123 - val_mae: 0.0794
# Epoch 9/20
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5115e-04 - mae: 0.0217 - val_loss: 0.0105 - val_mae: 0.0840
# Epoch 10/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0196 - val_mae: 0.1010
# Epoch 11/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0243 - val_loss: 0.0108 - val_mae: 0.0845
# Epoch 12/20
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4883e-04 - mae: 0.0217 - val_loss: 0.0119 - val_mae: 0.0799
# Epoch 13/20
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9370e-04 - mae: 0.0224 - val_loss: 0.0104 - val_mae: 0.0826
# Epoch 14/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0175 - val_mae: 0.0926
# Epoch 15/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 0.0156 - val_mae: 0.0858
# Epoch 16/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0111 - val_mae: 0.0804
# Epoch 17/20
# 228/228 [==============================] - 2s 7ms/step - loss: 9.4837e-04 - mae: 0.0216 - val_loss: 0.0104 - val_mae: 0.0857
# Epoch 18/20
# 228/228 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0233 - val_loss: 0.0128 - val_mae: 0.0793
# Epoch 19/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0226 - val_loss: 0.0103 - val_mae: 0.0834
# Epoch 20/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 0.0122 - val_mae: 0.0794

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
results_rnn2 = evaluate_model(
    rnn_model2,
    "RNN_MODEL2",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn2
# Out:
# Evaluation of RNN_MODEL2:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0009 	 | 	test mae: 0.0226
# Val loss: 0.0122 	 | 	val mae: 0.0794
# Train loss: 0.0008 	 | 	train mae: 0.019
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL2     0.0009    0.0226    0.0122   0.0794      0.0008      0.019

# %%
train_preds2 = rnn_model2.predict(train)
val_preds2 = rnn_model2.predict(val)
test_preds2 = rnn_model2.predict(test)

print(f"Shape of train_preds: {train_preds2.shape}")
print(f"Shape of val_preds: {val_preds2.shape}")
print(f"Shape of test_preds: {test_preds2.shape}")
# Out:
# 229/229 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds2.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds2.ravel(), "val_preds": val_preds2.ravel(), "test_preds": test_preds2.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Test 3

# %%
# Shared attributes:
loss_function = 'mse'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 70

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
rnn_model3 = Sequential()
rnn_model3.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model3.add(Dense(1))

rnn_model3.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model3.summary()

history_rnn_model3 = rnn_model3.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_2 (SimpleRNN)    (None, 1, 128)            16640
#
#  dense_2 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\2645475868.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model3 = rnn_model3.fit_generator(
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0188 - mae: 0.0661 - val_loss: 0.0187 - val_mae: 0.0907
# Epoch 2/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0024 - mae: 0.0307 - val_loss: 0.0113 - val_mae: 0.0870
# Epoch 3/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0016 - mae: 0.0258 - val_loss: 0.0131 - val_mae: 0.0807
# Epoch 4/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0016 - mae: 0.0278 - val_loss: 0.0105 - val_mae: 0.0835
# Epoch 5/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0233 - val_loss: 0.0133 - val_mae: 0.0806
# Epoch 6/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 0.0148 - val_mae: 0.0830
# Epoch 7/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0233 - val_loss: 0.0116 - val_mae: 0.0790
# Epoch 8/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6914e-04 - mae: 0.0222 - val_loss: 0.0164 - val_mae: 0.0899
# Epoch 9/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5712e-04 - mae: 0.0220 - val_loss: 0.0125 - val_mae: 0.0791
# Epoch 10/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0234 - val_loss: 0.0124 - val_mae: 0.0794
# Epoch 11/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0234 - val_loss: 0.0112 - val_mae: 0.0807
# Epoch 12/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0108 - val_mae: 0.0867
# Epoch 13/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.1172e-04 - mae: 0.0213 - val_loss: 0.0122 - val_mae: 0.0791
# Epoch 14/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0109 - val_mae: 0.0835
# Epoch 15/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4318e-04 - mae: 0.0215 - val_loss: 0.0150 - val_mae: 0.0837
# Epoch 16/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0233 - val_loss: 0.0151 - val_mae: 0.0844
# Epoch 17/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4335e-04 - mae: 0.0214 - val_loss: 0.0124 - val_mae: 0.0791
# Epoch 18/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.8976e-04 - mae: 0.0223 - val_loss: 0.0104 - val_mae: 0.0799
# Epoch 19/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0227 - val_loss: 0.0126 - val_mae: 0.0793
# Epoch 20/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 0.0118 - val_mae: 0.0817
# Epoch 21/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0146 - val_mae: 0.0824
# Epoch 22/70
# 228/228 [==============================] - 2s 8ms/step - loss: 9.9836e-04 - mae: 0.0226 - val_loss: 0.0123 - val_mae: 0.0790
# Epoch 23/70
# 228/228 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0227 - val_loss: 0.0110 - val_mae: 0.0901
# Epoch 24/70
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0012 - mae: 0.0247 - val_loss: 0.0131 - val_mae: 0.0802
# Epoch 25/70
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0011 - mae: 0.0228 - val_loss: 0.0133 - val_mae: 0.0801
# Epoch 26/70
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0113 - val_mae: 0.0793
# Epoch 27/70
# 228/228 [==============================] - 2s 11ms/step - loss: 9.3180e-04 - mae: 0.0216 - val_loss: 0.0110 - val_mae: 0.0814
# Epoch 28/70
# 228/228 [==============================] - 2s 10ms/step - loss: 9.7016e-04 - mae: 0.0222 - val_loss: 0.0135 - val_mae: 0.0806
# Epoch 29/70
# 228/228 [==============================] - 3s 15ms/step - loss: 9.7162e-04 - mae: 0.0225 - val_loss: 0.0112 - val_mae: 0.0813
# Epoch 30/70
# 228/228 [==============================] - 3s 14ms/step - loss: 9.6037e-04 - mae: 0.0220 - val_loss: 0.0104 - val_mae: 0.0816
# Epoch 31/70
# 228/228 [==============================] - 3s 12ms/step - loss: 9.3464e-04 - mae: 0.0215 - val_loss: 0.0114 - val_mae: 0.0801
# Epoch 32/70
# 228/228 [==============================] - 3s 14ms/step - loss: 9.2219e-04 - mae: 0.0215 - val_loss: 0.0112 - val_mae: 0.0795
# Epoch 33/70
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0010 - mae: 0.0227 - val_loss: 0.0109 - val_mae: 0.0809
# Epoch 34/70
# 228/228 [==============================] - 2s 10ms/step - loss: 9.3672e-04 - mae: 0.0214 - val_loss: 0.0117 - val_mae: 0.0802
# Epoch 35/70
# 228/228 [==============================] - 3s 13ms/step - loss: 9.8587e-04 - mae: 0.0221 - val_loss: 0.0108 - val_mae: 0.0819
# Epoch 36/70
# 228/228 [==============================] - 3s 12ms/step - loss: 9.8108e-04 - mae: 0.0225 - val_loss: 0.0142 - val_mae: 0.0817
# Epoch 37/70
# 228/228 [==============================] - 3s 15ms/step - loss: 9.9957e-04 - mae: 0.0222 - val_loss: 0.0112 - val_mae: 0.0792
# Epoch 38/70
# 228/228 [==============================] - 2s 8ms/step - loss: 9.9706e-04 - mae: 0.0220 - val_loss: 0.0104 - val_mae: 0.0814
# Epoch 39/70
# 228/228 [==============================] - 2s 9ms/step - loss: 9.7199e-04 - mae: 0.0220 - val_loss: 0.0103 - val_mae: 0.0850
# Epoch 40/70
# 228/228 [==============================] - 2s 10ms/step - loss: 9.4453e-04 - mae: 0.0217 - val_loss: 0.0105 - val_mae: 0.0818
# Epoch 41/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.3117e-04 - mae: 0.0215 - val_loss: 0.0118 - val_mae: 0.0792
# Epoch 42/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.4004e-04 - mae: 0.0214 - val_loss: 0.0111 - val_mae: 0.0802
# Epoch 43/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.7017e-04 - mae: 0.0220 - val_loss: 0.0108 - val_mae: 0.0888
# Epoch 44/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 0.0106 - val_mae: 0.0831
# Epoch 45/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.2515e-04 - mae: 0.0214 - val_loss: 0.0105 - val_mae: 0.0840
# Epoch 46/70
# 228/228 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0114 - val_mae: 0.0801
# Epoch 47/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5098e-04 - mae: 0.0218 - val_loss: 0.0105 - val_mae: 0.0805
# Epoch 48/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4062e-04 - mae: 0.0213 - val_loss: 0.0108 - val_mae: 0.0810
# Epoch 49/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.8717e-04 - mae: 0.0222 - val_loss: 0.0110 - val_mae: 0.0802
# Epoch 50/70
# 228/228 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0137 - val_mae: 0.0804
# Epoch 51/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.5971e-04 - mae: 0.0219 - val_loss: 0.0111 - val_mae: 0.0801
# Epoch 52/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.7846e-04 - mae: 0.0220 - val_loss: 0.0115 - val_mae: 0.0786
# Epoch 53/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.0018e-04 - mae: 0.0210 - val_loss: 0.0103 - val_mae: 0.0801
# Epoch 54/70
# 228/228 [==============================] - 1s 7ms/step - loss: 9.4072e-04 - mae: 0.0215 - val_loss: 0.0106 - val_mae: 0.0808
# Epoch 55/70
# 228/228 [==============================] - 1s 6ms/step - loss: 8.9658e-04 - mae: 0.0211 - val_loss: 0.0114 - val_mae: 0.0792
# Epoch 56/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0022 - mae: 0.0303 - val_loss: 0.0109 - val_mae: 0.0819
# Epoch 57/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.7000e-04 - mae: 0.0217 - val_loss: 0.0107 - val_mae: 0.0802
# Epoch 58/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9943e-04 - mae: 0.0228 - val_loss: 0.0102 - val_mae: 0.0832
# Epoch 59/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.2007e-04 - mae: 0.0215 - val_loss: 0.0109 - val_mae: 0.0796
# Epoch 60/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.8715e-04 - mae: 0.0224 - val_loss: 0.0150 - val_mae: 0.0837
# Epoch 61/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0226 - val_loss: 0.0125 - val_mae: 0.0786
# Epoch 62/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4410e-04 - mae: 0.0223 - val_loss: 0.0107 - val_mae: 0.0804
# Epoch 63/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4568e-04 - mae: 0.0215 - val_loss: 0.0130 - val_mae: 0.0790
# Epoch 64/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5475e-04 - mae: 0.0217 - val_loss: 0.0124 - val_mae: 0.0786
# Epoch 65/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0226 - val_loss: 0.0126 - val_mae: 0.0785
# Epoch 66/70
# 228/228 [==============================] - 2s 8ms/step - loss: 9.3003e-04 - mae: 0.0214 - val_loss: 0.0132 - val_mae: 0.0794
# Epoch 67/70
# 228/228 [==============================] - 3s 14ms/step - loss: 9.2143e-04 - mae: 0.0215 - val_loss: 0.0119 - val_mae: 0.0787
# Epoch 68/70
# 228/228 [==============================] - 2s 10ms/step - loss: 9.2360e-04 - mae: 0.0213 - val_loss: 0.0113 - val_mae: 0.0793
# Epoch 69/70
# 228/228 [==============================] - 3s 12ms/step - loss: 9.1241e-04 - mae: 0.0212 - val_loss: 0.0129 - val_mae: 0.0791
# Epoch 70/70
# 228/228 [==============================] - 3s 12ms/step - loss: 9.2835e-04 - mae: 0.0214 - val_loss: 0.0104 - val_mae: 0.0810

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
results_rnn3 = evaluate_model(
    rnn_model3,
    "RNN_MODEL3",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn3
# Out:
# Evaluation of RNN_MODEL3:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0023 	 | 	test mae: 0.0419
# Val loss: 0.0104 	 | 	val mae: 0.081
# Train loss: 0.0009 	 | 	train mae: 0.0221
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL3     0.0023    0.0419    0.0104    0.081      0.0009     0.0221

# %%
train_preds3 = rnn_model3.predict(train)
val_preds3 = rnn_model3.predict(val)
test_preds3 = rnn_model3.predict(test)

print(f"Shape of train_preds: {train_preds3.shape}")
print(f"Shape of val_preds: {val_preds3.shape}")
print(f"Shape of test_preds: {test_preds3.shape}")
# Out:
# 229/229 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds3.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds3.ravel(), "val_preds": val_preds3.ravel(), "test_preds": test_preds3.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Test 4

# %%
# Shared attributes:
loss_function = 'mae'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 50

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
rnn_model4 = Sequential()
rnn_model4.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model4.add(Dense(1))

rnn_model4.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model4.summary()

history_rnn_model4 = rnn_model4.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)

rnn_model4.save('rnn_model4.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 1, 128)            16640
#
#  dense_3 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\2514207992.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model4 = rnn_model4.fit_generator(
# 228/228 [==============================] - 3s 8ms/step - loss: 0.0439 - mae: 0.0439 - val_loss: 0.0892 - val_mae: 0.0892
# Epoch 2/50
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0264 - mae: 0.0264 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 3/50
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0242 - mae: 0.0242 - val_loss: 0.0879 - val_mae: 0.0879
# Epoch 4/50
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0809 - val_mae: 0.0809
# Epoch 5/50
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0230 - mae: 0.0230 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 6/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 7/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0794 - val_mae: 0.0794
# Epoch 8/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0221 - mae: 0.0221 - val_loss: 0.0817 - val_mae: 0.0817
# Epoch 9/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0809 - val_mae: 0.0809
# Epoch 10/50
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0895 - val_mae: 0.0895
# Epoch 11/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0812 - val_mae: 0.0812
# Epoch 12/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0216 - mae: 0.0216 - val_loss: 0.0820 - val_mae: 0.0820
# Epoch 13/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0216 - mae: 0.0216 - val_loss: 0.0808 - val_mae: 0.0808
# Epoch 14/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0817 - val_mae: 0.0817
# Epoch 15/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 16/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0232 - mae: 0.0232 - val_loss: 0.0846 - val_mae: 0.0846
# Epoch 17/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0217 - mae: 0.0217 - val_loss: 0.0822 - val_mae: 0.0822
# Epoch 18/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0798 - val_mae: 0.0798
# Epoch 19/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0789 - val_mae: 0.0789
# Epoch 20/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0819 - val_mae: 0.0819
# Epoch 21/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0815 - val_mae: 0.0815
# Epoch 22/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0224 - mae: 0.0224 - val_loss: 0.0822 - val_mae: 0.0822
# Epoch 23/50
# 228/228 [==============================] - 1s 7ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 24/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0219 - mae: 0.0219 - val_loss: 0.0789 - val_mae: 0.0789
# Epoch 25/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0204 - mae: 0.0204 - val_loss: 0.0798 - val_mae: 0.0798
# Epoch 26/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 27/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0215 - mae: 0.0215 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 28/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0800 - val_mae: 0.0800
# Epoch 29/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0823 - val_mae: 0.0823
# Epoch 30/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0216 - mae: 0.0216 - val_loss: 0.0829 - val_mae: 0.0829
# Epoch 31/50
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 32/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0808 - val_mae: 0.0808
# Epoch 33/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0210 - mae: 0.0210 - val_loss: 0.0816 - val_mae: 0.0816
# Epoch 34/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0817 - val_mae: 0.0817
# Epoch 35/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0795 - val_mae: 0.0795
# Epoch 36/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0814 - val_mae: 0.0814
# Epoch 37/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0217 - mae: 0.0217 - val_loss: 0.0790 - val_mae: 0.0790
# Epoch 38/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0205 - mae: 0.0205 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 39/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0797 - val_mae: 0.0797
# Epoch 40/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0210 - mae: 0.0210 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 41/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0210 - mae: 0.0210 - val_loss: 0.0797 - val_mae: 0.0797
# Epoch 42/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0789 - val_mae: 0.0789
# Epoch 43/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0213 - mae: 0.0213 - val_loss: 0.0790 - val_mae: 0.0790
# Epoch 44/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0203 - mae: 0.0203 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 45/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0213 - mae: 0.0213 - val_loss: 0.0825 - val_mae: 0.0825
# Epoch 46/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 47/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0213 - mae: 0.0213 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 48/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0203 - mae: 0.0203 - val_loss: 0.0794 - val_mae: 0.0794
# Epoch 49/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0827 - val_mae: 0.0827
# Epoch 50/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0809 - val_mae: 0.0809

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
results_rnn4 = evaluate_model(
    rnn_model4,
    "RNN_MODEL4",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn4
# Out:
# Evaluation of RNN_MODEL4:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0351 	 | 	test mae: 0.0351
# Val loss: 0.0809 	 | 	val mae: 0.0809
# Train loss: 0.0204 	 | 	train mae: 0.0204
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL4     0.0351    0.0351    0.0809   0.0809      0.0204     0.0204

# %%
train_preds4 = rnn_model4.predict(train)
val_preds4 = rnn_model4.predict(val)
test_preds4 = rnn_model4.predict(test)

print(f"Shape of train_preds: {train_preds4.shape}")
print(f"Shape of val_preds: {val_preds4.shape}")
print(f"Shape of test_preds: {test_preds4.shape}")
# Out:
# 229/229 [==============================] - 0s 988us/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds4.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds4.ravel(), "val_preds": val_preds4.ravel(), "test_preds": test_preds4.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Test 5

# %%
# Shared attributes:
loss_function = 'mae'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 20

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
rnn_model5 = Sequential()
rnn_model5.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model5.add(Dense(1))

rnn_model5.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model5.summary()

history_rnn_model5 = rnn_model5.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_4 (SimpleRNN)    (None, 1, 128)            16640
#
#  dense_4 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\2429787514.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model5 = rnn_model5.fit_generator(
# 228/228 [==============================] - 3s 7ms/step - loss: 0.0566 - mae: 0.0566 - val_loss: 0.1006 - val_mae: 0.1006
# Epoch 2/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0276 - mae: 0.0276 - val_loss: 0.0804 - val_mae: 0.0804
# Epoch 3/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0273 - mae: 0.0273 - val_loss: 0.0828 - val_mae: 0.0828
# Epoch 4/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0253 - mae: 0.0253 - val_loss: 0.1050 - val_mae: 0.1050
# Epoch 5/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0225 - mae: 0.0225 - val_loss: 0.0806 - val_mae: 0.0806
# Epoch 6/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0230 - mae: 0.0230 - val_loss: 0.0816 - val_mae: 0.0816
# Epoch 7/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0215 - mae: 0.0215 - val_loss: 0.0820 - val_mae: 0.0820
# Epoch 8/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0216 - mae: 0.0216 - val_loss: 0.0850 - val_mae: 0.0850
# Epoch 9/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0224 - mae: 0.0224 - val_loss: 0.0837 - val_mae: 0.0837
# Epoch 10/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0252 - mae: 0.0252 - val_loss: 0.0898 - val_mae: 0.0898
# Epoch 11/20
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0800 - val_mae: 0.0800
# Epoch 12/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0809 - val_mae: 0.0809
# Epoch 13/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0230 - mae: 0.0230 - val_loss: 0.0819 - val_mae: 0.0819
# Epoch 14/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0807 - val_mae: 0.0807
# Epoch 15/20
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0219 - mae: 0.0219 - val_loss: 0.0842 - val_mae: 0.0842
# Epoch 16/20
# 228/228 [==============================] - 2s 11ms/step - loss: 0.0221 - mae: 0.0221 - val_loss: 0.0805 - val_mae: 0.0805
# Epoch 17/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 18/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0883 - val_mae: 0.0883
# Epoch 19/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 20/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0800 - val_mae: 0.0800

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
results_rnn5 = evaluate_model(
    rnn_model5,
    "RNN_MODEL5",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn5
# Out:
# Evaluation of RNN_MODEL5:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0209 	 | 	test mae: 0.0209
# Val loss: 0.08 	 | 	val mae: 0.08
# Train loss: 0.0191 	 | 	train mae: 0.0191
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL5     0.0209    0.0209      0.08     0.08      0.0191     0.0191

# %%
train_preds5 = rnn_model5.predict(train)
val_preds5 = rnn_model5.predict(val)
test_preds5 = rnn_model5.predict(test)

print(f"Shape of train_preds: {train_preds5.shape}")
print(f"Shape of val_preds: {val_preds5.shape}")
print(f"Shape of test_preds: {test_preds5.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds5.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds5.ravel(), "val_preds": val_preds5.ravel(), "test_preds": test_preds5.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Test 6

# %%
# Shared attributes:
loss_function = 'mae'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 70

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
rnn_model6 = Sequential()
rnn_model6.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model6.add(Dense(1))

rnn_model6.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model6.summary()

history_rnn_model6 = rnn_model6.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_5 (SimpleRNN)    (None, 1, 128)            16640
#
#  dense_5 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1149539611.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model6 = rnn_model6.fit_generator(
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0718 - mae: 0.0718 - val_loss: 0.0980 - val_mae: 0.0980
# Epoch 2/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0328 - mae: 0.0328 - val_loss: 0.0833 - val_mae: 0.0833
# Epoch 3/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0243 - mae: 0.0243 - val_loss: 0.0801 - val_mae: 0.0801
# Epoch 4/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 5/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0806 - val_mae: 0.0806
# Epoch 6/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0227 - mae: 0.0227 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 7/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0830 - val_mae: 0.0830
# Epoch 8/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0839 - val_mae: 0.0839
# Epoch 9/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 10/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0226 - mae: 0.0226 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 11/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 12/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0800 - val_mae: 0.0800
# Epoch 13/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0841 - val_mae: 0.0841
# Epoch 14/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0814 - val_mae: 0.0814
# Epoch 15/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0234 - mae: 0.0234 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 16/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0822 - val_mae: 0.0822
# Epoch 17/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0808 - val_mae: 0.0808
# Epoch 18/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 19/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0225 - mae: 0.0225 - val_loss: 0.0827 - val_mae: 0.0827
# Epoch 20/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0818 - val_mae: 0.0818
# Epoch 21/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0215 - mae: 0.0215 - val_loss: 0.0835 - val_mae: 0.0835
# Epoch 22/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0240 - mae: 0.0240 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 23/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 24/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0803 - val_mae: 0.0803
# Epoch 25/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 26/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0219 - mae: 0.0219 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 27/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0224 - mae: 0.0224 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 28/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0812 - val_mae: 0.0812
# Epoch 29/70
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0794 - val_mae: 0.0794
# Epoch 30/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0208 - mae: 0.0208 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 31/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0216 - mae: 0.0216 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 32/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0804 - val_mae: 0.0804
# Epoch 33/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0221 - mae: 0.0221 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 34/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 35/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0208 - mae: 0.0208 - val_loss: 0.0852 - val_mae: 0.0852
# Epoch 36/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0800 - val_mae: 0.0800
# Epoch 37/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0823 - val_mae: 0.0823
# Epoch 38/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0804 - val_mae: 0.0804
# Epoch 39/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0791 - val_mae: 0.0791
# Epoch 40/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0215 - mae: 0.0215 - val_loss: 0.0823 - val_mae: 0.0823
# Epoch 41/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0210 - mae: 0.0210 - val_loss: 0.0811 - val_mae: 0.0811
# Epoch 42/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0205 - mae: 0.0205 - val_loss: 0.0813 - val_mae: 0.0813
# Epoch 43/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0805 - val_mae: 0.0805
# Epoch 44/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0828 - val_mae: 0.0828
# Epoch 45/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0797 - val_mae: 0.0797
# Epoch 46/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0797 - val_mae: 0.0797
# Epoch 47/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 48/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0837 - val_mae: 0.0837
# Epoch 49/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0204 - mae: 0.0204 - val_loss: 0.0797 - val_mae: 0.0797
# Epoch 50/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0816 - val_mae: 0.0816
# Epoch 51/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0804 - val_mae: 0.0804
# Epoch 52/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0797 - val_mae: 0.0797
# Epoch 53/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0205 - mae: 0.0205 - val_loss: 0.0807 - val_mae: 0.0807
# Epoch 54/70
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 55/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0219 - mae: 0.0219 - val_loss: 0.0791 - val_mae: 0.0791
# Epoch 56/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0205 - mae: 0.0205 - val_loss: 0.0785 - val_mae: 0.0785
# Epoch 57/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0214 - mae: 0.0214 - val_loss: 0.0805 - val_mae: 0.0805
# Epoch 58/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0801 - val_mae: 0.0801
# Epoch 59/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0792 - val_mae: 0.0792
# Epoch 60/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0810 - val_mae: 0.0810
# Epoch 61/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0206 - mae: 0.0206 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 62/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0219 - mae: 0.0219 - val_loss: 0.0792 - val_mae: 0.0792
# Epoch 63/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0793 - val_mae: 0.0793
# Epoch 64/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0208 - mae: 0.0208 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 65/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0205 - mae: 0.0205 - val_loss: 0.0806 - val_mae: 0.0806
# Epoch 66/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0203 - mae: 0.0203 - val_loss: 0.0803 - val_mae: 0.0803
# Epoch 67/70
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0791 - val_mae: 0.0791
# Epoch 68/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0203 - mae: 0.0203 - val_loss: 0.0801 - val_mae: 0.0801
# Epoch 69/70
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0202 - mae: 0.0202 - val_loss: 0.0818 - val_mae: 0.0818
# Epoch 70/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0793 - val_mae: 0.0793

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
results_rnn6 = evaluate_model(
    rnn_model6,
    "RNN_MODEL6",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn6
# Out:
# Evaluation of RNN_MODEL6:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0239 	 | 	test mae: 0.0239
# Val loss: 0.0793 	 | 	val mae: 0.0793
# Train loss: 0.0192 	 | 	train mae: 0.0192
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL6     0.0239    0.0239    0.0793   0.0793      0.0192     0.0192

# %%
train_preds6 = rnn_model6.predict(train)
val_preds6 = rnn_model6.predict(val)
test_preds6 = rnn_model6.predict(test)

print(f"Shape of train_preds: {train_preds6.shape}")
print(f"Shape of val_preds: {val_preds6.shape}")
print(f"Shape of test_preds: {test_preds6.shape}")
# Out:
# 229/229 [==============================] - 0s 992us/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds6.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds6.ravel(), "val_preds": val_preds6.ravel(), "test_preds": test_preds6.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Test 7

# %%
# Shared attributes:
loss_function = 'mean_squared_error'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 50

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
rnn_model7 = Sequential()
rnn_model7.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model7.add(Dense(1))

rnn_model7.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model7.summary()

history_rnn_model7 = rnn_model2.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_6 (SimpleRNN)    (None, 1, 128)            16640
#
#  dense_6 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
#  20/228 [=>............................] - ETA: 1s - loss: 9.9723e-04 - mae: 0.0226
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\3313969793.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model7 = rnn_model2.fit_generator(
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0117 - val_mae: 0.0795
# Epoch 2/50
# 228/228 [==============================] - 3s 11ms/step - loss: 0.0010 - mae: 0.0223 - val_loss: 0.0132 - val_mae: 0.0798
# Epoch 3/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0230 - val_loss: 0.0110 - val_mae: 0.0803
# Epoch 4/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4503e-04 - mae: 0.0214 - val_loss: 0.0117 - val_mae: 0.0789
# Epoch 5/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4081e-04 - mae: 0.0215 - val_loss: 0.0106 - val_mae: 0.0877
# Epoch 6/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 0.0125 - val_mae: 0.0790
# Epoch 7/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5916e-04 - mae: 0.0221 - val_loss: 0.0112 - val_mae: 0.0787
# Epoch 8/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.2891e-04 - mae: 0.0213 - val_loss: 0.0104 - val_mae: 0.0815
# Epoch 9/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0224 - val_loss: 0.0107 - val_mae: 0.0804
# Epoch 10/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0111 - val_mae: 0.0787
# Epoch 11/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.2408e-04 - mae: 0.0214 - val_loss: 0.0116 - val_mae: 0.0790
# Epoch 12/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 0.0120 - val_mae: 0.0797
# Epoch 13/50
# 228/228 [==============================] - 1s 5ms/step - loss: 9.6573e-04 - mae: 0.0221 - val_loss: 0.0125 - val_mae: 0.0789
# Epoch 14/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0104 - val_mae: 0.0819
# Epoch 15/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3596e-04 - mae: 0.0217 - val_loss: 0.0105 - val_mae: 0.0846
# Epoch 16/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.8826e-04 - mae: 0.0223 - val_loss: 0.0104 - val_mae: 0.0815
# Epoch 17/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6054e-04 - mae: 0.0217 - val_loss: 0.0110 - val_mae: 0.0804
# Epoch 18/50
# 228/228 [==============================] - 1s 6ms/step - loss: 8.9091e-04 - mae: 0.0212 - val_loss: 0.0118 - val_mae: 0.0782
# Epoch 19/50
# 228/228 [==============================] - 1s 6ms/step - loss: 8.9556e-04 - mae: 0.0211 - val_loss: 0.0111 - val_mae: 0.0824
# Epoch 20/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9574e-04 - mae: 0.0223 - val_loss: 0.0102 - val_mae: 0.0842
# Epoch 21/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6678e-04 - mae: 0.0222 - val_loss: 0.0115 - val_mae: 0.0791
# Epoch 22/50
# 228/228 [==============================] - 1s 6ms/step - loss: 8.9997e-04 - mae: 0.0211 - val_loss: 0.0128 - val_mae: 0.0792
# Epoch 23/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.1423e-04 - mae: 0.0214 - val_loss: 0.0124 - val_mae: 0.0788
# Epoch 24/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0115 - val_mae: 0.0795
# Epoch 25/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5734e-04 - mae: 0.0218 - val_loss: 0.0129 - val_mae: 0.0794
# Epoch 26/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0226 - val_loss: 0.0135 - val_mae: 0.0797
# Epoch 27/50
# 228/228 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0226 - val_loss: 0.0115 - val_mae: 0.0792
# Epoch 28/50
# 228/228 [==============================] - 1s 5ms/step - loss: 9.0780e-04 - mae: 0.0213 - val_loss: 0.0124 - val_mae: 0.0793
# Epoch 29/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3260e-04 - mae: 0.0213 - val_loss: 0.0112 - val_mae: 0.0924
# Epoch 30/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5193e-04 - mae: 0.0216 - val_loss: 0.0108 - val_mae: 0.0893
# Epoch 31/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0106 - val_mae: 0.0845
# Epoch 32/50
# 228/228 [==============================] - 2s 7ms/step - loss: 8.8741e-04 - mae: 0.0209 - val_loss: 0.0115 - val_mae: 0.0788
# Epoch 33/50
# 228/228 [==============================] - 2s 7ms/step - loss: 8.8428e-04 - mae: 0.0206 - val_loss: 0.0113 - val_mae: 0.0791
# Epoch 34/50
# 228/228 [==============================] - 2s 7ms/step - loss: 9.4779e-04 - mae: 0.0216 - val_loss: 0.0113 - val_mae: 0.0820
# Epoch 35/50
# 228/228 [==============================] - 2s 7ms/step - loss: 9.3351e-04 - mae: 0.0213 - val_loss: 0.0110 - val_mae: 0.0794
# Epoch 36/50
# 228/228 [==============================] - 2s 7ms/step - loss: 9.2879e-04 - mae: 0.0215 - val_loss: 0.0108 - val_mae: 0.0804
# Epoch 37/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0110 - val_mae: 0.0802
# Epoch 38/50
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0010 - mae: 0.0223 - val_loss: 0.0125 - val_mae: 0.0789
# Epoch 39/50
# 228/228 [==============================] - 2s 9ms/step - loss: 8.9897e-04 - mae: 0.0211 - val_loss: 0.0122 - val_mae: 0.0786
# Epoch 40/50
# 228/228 [==============================] - 2s 7ms/step - loss: 9.0922e-04 - mae: 0.0211 - val_loss: 0.0109 - val_mae: 0.0795
# Epoch 41/50
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 0.0109 - val_mae: 0.0802
# Epoch 42/50
# 228/228 [==============================] - 2s 7ms/step - loss: 9.2222e-04 - mae: 0.0215 - val_loss: 0.0103 - val_mae: 0.0814
# Epoch 43/50
# 228/228 [==============================] - 2s 7ms/step - loss: 9.0148e-04 - mae: 0.0212 - val_loss: 0.0110 - val_mae: 0.0798
# Epoch 44/50
# 228/228 [==============================] - 2s 9ms/step - loss: 8.9315e-04 - mae: 0.0208 - val_loss: 0.0120 - val_mae: 0.0790
# Epoch 45/50
# 228/228 [==============================] - 2s 9ms/step - loss: 9.2952e-04 - mae: 0.0211 - val_loss: 0.0115 - val_mae: 0.0789
# Epoch 46/50
# 228/228 [==============================] - 2s 8ms/step - loss: 8.6483e-04 - mae: 0.0205 - val_loss: 0.0114 - val_mae: 0.0789
# Epoch 47/50
# 228/228 [==============================] - 2s 8ms/step - loss: 9.7459e-04 - mae: 0.0218 - val_loss: 0.0135 - val_mae: 0.0800
# Epoch 48/50
# 228/228 [==============================] - 1s 6ms/step - loss: 9.0675e-04 - mae: 0.0212 - val_loss: 0.0125 - val_mae: 0.0786
# Epoch 49/50
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0118 - val_mae: 0.0787
# Epoch 50/50
# 228/228 [==============================] - 2s 8ms/step - loss: 9.0664e-04 - mae: 0.0210 - val_loss: 0.0132 - val_mae: 0.0795

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
results_rnn7 = evaluate_model(
    rnn_model7,
    "RNN_MODEL7",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn7
# Out:
# Evaluation of RNN_MODEL7:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
# Test loss: 0.4301 	 | 	test mae: 0.6438
# Val loss: 0.3717 	 | 	val mae: 0.5875
# Train loss: 0.1761 	 | 	train mae: 0.3746
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL7     0.4301    0.6438    0.3717   0.5875      0.1761     0.3746

# %%
train_preds7 = rnn_model7.predict(train)
val_preds7 = rnn_model7.predict(val)
test_preds7 = rnn_model7.predict(test)

print(f"Shape of train_preds: {train_preds7.shape}")
print(f"Shape of val_preds: {val_preds7.shape}")
print(f"Shape of test_preds: {test_preds7.shape}")
# Out:
# 229/229 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds7.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds7.ravel(), "val_preds": val_preds7.ravel(), "test_preds": test_preds7.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Test 8

# %%
# Shared attributes:
loss_function = 'mean_squared_error'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 20

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
rnn_model8 = Sequential()
rnn_model8.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model8.add(Dense(1))

rnn_model8.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model8.summary()

history_rnn_model8 = rnn_model8.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_7 (SimpleRNN)    (None, 1, 128)            16640
#
#  dense_7 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1718980272.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model8 = rnn_model8.fit_generator(
# 228/228 [==============================] - 3s 7ms/step - loss: 0.0060 - mae: 0.0401 - val_loss: 0.0115 - val_mae: 0.0899
# Epoch 2/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0244 - val_loss: 0.0113 - val_mae: 0.0814
# Epoch 3/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0250 - val_loss: 0.0126 - val_mae: 0.0800
# Epoch 4/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0234 - val_loss: 0.0151 - val_mae: 0.0844
# Epoch 5/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 0.0137 - val_mae: 0.0810
# Epoch 6/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0249 - val_loss: 0.0139 - val_mae: 0.0819
# Epoch 7/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0133 - val_mae: 0.0800
# Epoch 8/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0196 - val_mae: 0.1015
# Epoch 9/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0109 - val_mae: 0.0829
# Epoch 10/20
# 228/228 [==============================] - 1s 6ms/step - loss: 9.7104e-04 - mae: 0.0218 - val_loss: 0.0129 - val_mae: 0.0799
# Epoch 11/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0233 - val_loss: 0.0134 - val_mae: 0.0805
# Epoch 12/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0233 - val_loss: 0.0113 - val_mae: 0.0835
# Epoch 13/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0224 - val_loss: 0.0110 - val_mae: 0.0807
# Epoch 14/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 0.0107 - val_mae: 0.0864
# Epoch 15/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0122 - val_mae: 0.0793
# Epoch 16/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0148 - val_mae: 0.0847
# Epoch 17/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0242 - val_loss: 0.0128 - val_mae: 0.0796
# Epoch 18/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0234 - val_loss: 0.0107 - val_mae: 0.0847
# Epoch 19/20
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9498e-04 - mae: 0.0224 - val_loss: 0.0117 - val_mae: 0.0811
# Epoch 20/20
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0226 - val_loss: 0.0118 - val_mae: 0.0797

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
results_rnn8 = evaluate_model(
    rnn_model8,
    "RNN_MODEL8",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn8
# Out:
# Evaluation of RNN_MODEL8:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0011 	 | 	test mae: 0.0252
# Val loss: 0.0118 	 | 	val mae: 0.0797
# Train loss: 0.0008 	 | 	train mae: 0.0195
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL8     0.0011    0.0252    0.0118   0.0797      0.0008     0.0195

# %%
train_preds8 = rnn_model8.predict(train)
val_preds8 = rnn_model8.predict(val)
test_preds8 = rnn_model8.predict(test)

print(f"Shape of train_preds: {train_preds8.shape}")
print(f"Shape of val_preds: {val_preds8.shape}")
print(f"Shape of test_preds: {test_preds8.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1000us/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds8.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds8.ravel(), "val_preds": val_preds8.ravel(), "test_preds": test_preds8.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Test 9

# %%
# Shared attributes:
loss_function = 'mean_squared_error'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 70

num_samples, num_input_features = train.shape

# %%
# Define RNN's architecture here:
rnn_model9 = Sequential()
rnn_model9.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model9.add(Dense(1))

rnn_model9.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model9.summary()

history_rnn_model9 = rnn_model9.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_8 (SimpleRNN)    (None, 1, 128)            16640
#
#  dense_8 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/70
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\2677441085.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model9 = rnn_model9.fit_generator(
# 228/228 [==============================] - 3s 9ms/step - loss: 0.0085 - mae: 0.0486 - val_loss: 0.0110 - val_mae: 0.0824
# Epoch 2/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0017 - mae: 0.0301 - val_loss: 0.0121 - val_mae: 0.0791
# Epoch 3/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0234 - val_loss: 0.0156 - val_mae: 0.0868
# Epoch 4/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0231 - val_loss: 0.0123 - val_mae: 0.0789
# Epoch 5/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 0.0109 - val_mae: 0.0839
# Epoch 6/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 0.0232 - val_mae: 0.1158
# Epoch 7/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0230 - val_loss: 0.0139 - val_mae: 0.0819
# Epoch 8/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0010 - mae: 0.0230 - val_loss: 0.0102 - val_mae: 0.0826
# Epoch 9/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.8482e-04 - mae: 0.0221 - val_loss: 0.0116 - val_mae: 0.0791
# Epoch 10/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.8160e-04 - mae: 0.0222 - val_loss: 0.0121 - val_mae: 0.0793
# Epoch 11/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0245 - val_loss: 0.0151 - val_mae: 0.0836
# Epoch 12/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0245 - val_loss: 0.0117 - val_mae: 0.0801
# Epoch 13/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.7072e-04 - mae: 0.0222 - val_loss: 0.0142 - val_mae: 0.0819
# Epoch 14/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0234 - val_loss: 0.0130 - val_mae: 0.0813
# Epoch 15/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0010 - mae: 0.0224 - val_loss: 0.0113 - val_mae: 0.0808
# Epoch 16/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0114 - val_mae: 0.0796
# Epoch 17/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0230 - val_loss: 0.0125 - val_mae: 0.0800
# Epoch 18/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.0437e-04 - mae: 0.0210 - val_loss: 0.0146 - val_mae: 0.0824
# Epoch 19/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 0.0110 - val_mae: 0.0860
# Epoch 20/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0124 - val_mae: 0.0805
# Epoch 21/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0240 - val_loss: 0.0155 - val_mae: 0.0863
# Epoch 22/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4448e-04 - mae: 0.0213 - val_loss: 0.0147 - val_mae: 0.0828
# Epoch 23/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.1506e-04 - mae: 0.0210 - val_loss: 0.0111 - val_mae: 0.0808
# Epoch 24/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0101 - val_mae: 0.0826
# Epoch 25/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0114 - val_mae: 0.0806
# Epoch 26/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9697e-04 - mae: 0.0222 - val_loss: 0.0123 - val_mae: 0.0798
# Epoch 27/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4545e-04 - mae: 0.0216 - val_loss: 0.0114 - val_mae: 0.0819
# Epoch 28/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0244 - val_loss: 0.0119 - val_mae: 0.0793
# Epoch 29/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0120 - val_mae: 0.0790
# Epoch 30/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.5757e-04 - mae: 0.0217 - val_loss: 0.0105 - val_mae: 0.0804
# Epoch 31/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3920e-04 - mae: 0.0217 - val_loss: 0.0112 - val_mae: 0.0791
# Epoch 32/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.2561e-04 - mae: 0.0215 - val_loss: 0.0120 - val_mae: 0.0788
# Epoch 33/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0227 - val_loss: 0.0151 - val_mae: 0.0841
# Epoch 34/70
# 228/228 [==============================] - 2s 7ms/step - loss: 9.3499e-04 - mae: 0.0218 - val_loss: 0.0111 - val_mae: 0.0789
# Epoch 35/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6154e-04 - mae: 0.0221 - val_loss: 0.0106 - val_mae: 0.0813
# Epoch 36/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0105 - val_mae: 0.0807
# Epoch 37/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9201e-04 - mae: 0.0223 - val_loss: 0.0115 - val_mae: 0.0800
# Epoch 38/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9349e-04 - mae: 0.0224 - val_loss: 0.0153 - val_mae: 0.0845
# Epoch 39/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.8534e-04 - mae: 0.0220 - val_loss: 0.0122 - val_mae: 0.0793
# Epoch 40/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4404e-04 - mae: 0.0216 - val_loss: 0.0116 - val_mae: 0.0790
# Epoch 41/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5285e-04 - mae: 0.0221 - val_loss: 0.0119 - val_mae: 0.0787
# Epoch 42/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0240 - val_loss: 0.0113 - val_mae: 0.0840
# Epoch 43/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4693e-04 - mae: 0.0219 - val_loss: 0.0120 - val_mae: 0.0798
# Epoch 44/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3738e-04 - mae: 0.0216 - val_loss: 0.0113 - val_mae: 0.0794
# Epoch 45/70
# 228/228 [==============================] - 1s 6ms/step - loss: 8.8030e-04 - mae: 0.0207 - val_loss: 0.0104 - val_mae: 0.0825
# Epoch 46/70
# 228/228 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 0.0139 - val_mae: 0.0808
# Epoch 47/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3141e-04 - mae: 0.0216 - val_loss: 0.0126 - val_mae: 0.0790
# Epoch 48/70
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0010 - mae: 0.0232 - val_loss: 0.0103 - val_mae: 0.0853
# Epoch 49/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6398e-04 - mae: 0.0217 - val_loss: 0.0107 - val_mae: 0.0813
# Epoch 50/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6323e-04 - mae: 0.0224 - val_loss: 0.0141 - val_mae: 0.0820
# Epoch 51/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.9288e-04 - mae: 0.0223 - val_loss: 0.0125 - val_mae: 0.0785
# Epoch 52/70
# 228/228 [==============================] - 1s 6ms/step - loss: 8.8173e-04 - mae: 0.0208 - val_loss: 0.0124 - val_mae: 0.0788
# Epoch 53/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6284e-04 - mae: 0.0221 - val_loss: 0.0107 - val_mae: 0.0819
# Epoch 54/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4248e-04 - mae: 0.0216 - val_loss: 0.0113 - val_mae: 0.0796
# Epoch 55/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5947e-04 - mae: 0.0219 - val_loss: 0.0123 - val_mae: 0.0814
# Epoch 56/70
# 228/228 [==============================] - 1s 6ms/step - loss: 8.7901e-04 - mae: 0.0208 - val_loss: 0.0119 - val_mae: 0.0787
# Epoch 57/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.0440e-04 - mae: 0.0211 - val_loss: 0.0125 - val_mae: 0.0793
# Epoch 58/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.7731e-04 - mae: 0.0220 - val_loss: 0.0125 - val_mae: 0.0790
# Epoch 59/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.1833e-04 - mae: 0.0213 - val_loss: 0.0129 - val_mae: 0.0793
# Epoch 60/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.5616e-04 - mae: 0.0218 - val_loss: 0.0125 - val_mae: 0.0792
# Epoch 61/70
# 228/228 [==============================] - 1s 6ms/step - loss: 8.7690e-04 - mae: 0.0206 - val_loss: 0.0115 - val_mae: 0.0787
# Epoch 62/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3133e-04 - mae: 0.0216 - val_loss: 0.0121 - val_mae: 0.0786
# Epoch 63/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.4144e-04 - mae: 0.0221 - val_loss: 0.0116 - val_mae: 0.0789
# Epoch 64/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.6257e-04 - mae: 0.0220 - val_loss: 0.0133 - val_mae: 0.0798
# Epoch 65/70
# 228/228 [==============================] - 1s 6ms/step - loss: 8.8544e-04 - mae: 0.0207 - val_loss: 0.0121 - val_mae: 0.0785
# Epoch 66/70
# 228/228 [==============================] - 1s 6ms/step - loss: 8.8869e-04 - mae: 0.0207 - val_loss: 0.0118 - val_mae: 0.0795
# Epoch 67/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.3448e-04 - mae: 0.0216 - val_loss: 0.0111 - val_mae: 0.0798
# Epoch 68/70
# 228/228 [==============================] - 1s 6ms/step - loss: 8.6644e-04 - mae: 0.0206 - val_loss: 0.0119 - val_mae: 0.0794
# Epoch 69/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.0235e-04 - mae: 0.0211 - val_loss: 0.0110 - val_mae: 0.0799
# Epoch 70/70
# 228/228 [==============================] - 1s 6ms/step - loss: 9.1085e-04 - mae: 0.0210 - val_loss: 0.0108 - val_mae: 0.0831

# %% [markdown]
# Here's an utility function that will allow us to collect and compare results:

# %%
results_rnn9 = evaluate_model(
    rnn_model9,
    "RNN_MODEL9",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn9
# Out:
# Evaluation of RNN_MODEL9:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0026 	 | 	test mae: 0.0455
# Val loss: 0.0108 	 | 	val mae: 0.0831
# Train loss: 0.0011 	 | 	train mae: 0.0254
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL9     0.0026    0.0455    0.0108   0.0831      0.0011     0.0254

# %%
train_preds9 = rnn_model9.predict(train)
val_preds9 = rnn_model9.predict(val)
test_preds9 = rnn_model9.predict(test)

print(f"Shape of train_preds: {train_preds9.shape}")
print(f"Shape of val_preds: {val_preds9.shape}")
print(f"Shape of test_preds: {test_preds9.shape}")
# Out:
# 229/229 [==============================] - 0s 967us/step
# 3/3 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
# To correct the shapes (to plot the predictions) we need to apply the ravel function:
train_preds9.ravel().shape
# Out:
# (7311,)

# %% [markdown]
# Checking what is inside a batch:

# %% [markdown]
# Let's now plot our predictions to compare with the true labels:

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds9.ravel(), "val_preds": val_preds9.ravel(), "test_preds": test_preds9.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")

# %% [markdown]
# #### Results

# %%
results_rnn_all = pd.concat([results_rnn,
                             results_rnn2,
                             results_rnn3,
                             results_rnn4,
                             results_rnn5,
                             results_rnn6,
                             results_rnn7,
                             results_rnn8,
                             results_rnn9])
results_rnn_all
# Out:
#    model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  RNN_MODEL1     0.0011    0.0262    0.0115   0.0792      0.0008     0.0192
# 0  RNN_MODEL2     0.0009    0.0226    0.0122   0.0794      0.0008     0.0190
# 0  RNN_MODEL3     0.0023    0.0419    0.0104   0.0810      0.0009     0.0221
# 0  RNN_MODEL4     0.0351    0.0351    0.0809   0.0809      0.0204     0.0204
# 0  RNN_MODEL5     0.0209    0.0209    0.0800   0.0800      0.0191     0.0191
# 0  RNN_MODEL6     0.0239    0.0239    0.0793   0.0793      0.0192     0.0192
# 0  RNN_MODEL7     0.4301    0.6438    0.3717   0.5875      0.1761     0.3746
# 0  RNN_MODEL8     0.0011    0.0252    0.0118   0.0797      0.0008     0.0195
# 0  RNN_MODEL9     0.0026    0.0455    0.0108   0.0831      0.0011     0.0254

# %% [markdown]
# ### LSTM

# %% [markdown]
# #### Early stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    patience=10,
    monitor="val_loss",
    restore_best_weights=True
)

# %% [markdown]
# #### Test 1

# %%
# Shared attributes:
loss_function = 'mse'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 50

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
from tensorflow.keras.layers import LSTM

lstm_model = Sequential()
lstm_model.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model.add(Dense(1))

lstm_model.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 128)            66560
#
#  dense_9 (Dense)             (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model = lstm_model.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model.save('lstm_model.h5')
# Out:
# Epoch 1/50
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1374929510.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model = lstm_model.fit_generator(
# 228/228 [==============================] - 6s 19ms/step - loss: 0.0176 - mae: 0.0714 - val_loss: 0.0243 - val_mae: 0.1097
# Epoch 2/50
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0044 - mae: 0.0373 - val_loss: 0.0172 - val_mae: 0.0909
# Epoch 3/50
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0024 - mae: 0.0303 - val_loss: 0.0156 - val_mae: 0.0868
# Epoch 4/50
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0015 - mae: 0.0262 - val_loss: 0.0110 - val_mae: 0.0879
# Epoch 5/50
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0014 - mae: 0.0262 - val_loss: 0.0138 - val_mae: 0.0817
# Epoch 6/50
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0013 - mae: 0.0254 - val_loss: 0.0210 - val_mae: 0.1079
# Epoch 7/50
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 0.0164 - val_mae: 0.0890
# Epoch 8/50
# 228/228 [==============================] - 6s 27ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0122 - val_mae: 0.0800
# Epoch 9/50
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0108 - val_mae: 0.0817
# Epoch 10/50
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0010 - mae: 0.0230 - val_loss: 0.0140 - val_mae: 0.0813
# Epoch 11/50
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0115 - val_mae: 0.0802
# Epoch 12/50
# 228/228 [==============================] - 4s 18ms/step - loss: 9.5541e-04 - mae: 0.0220 - val_loss: 0.0176 - val_mae: 0.0925
# Epoch 13/50
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0011 - mae: 0.0236 - val_loss: 0.0136 - val_mae: 0.0805
# Epoch 14/50
# 228/228 [==============================] - 4s 17ms/step - loss: 9.2436e-04 - mae: 0.0216 - val_loss: 0.0125 - val_mae: 0.0796
# Epoch 15/50
# 228/228 [==============================] - 6s 26ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 0.0132 - val_mae: 0.0801
# Epoch 16/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.7617e-04 - mae: 0.0221 - val_loss: 0.0110 - val_mae: 0.0817
# Epoch 17/50
# 228/228 [==============================] - 4s 18ms/step - loss: 9.1457e-04 - mae: 0.0214 - val_loss: 0.0120 - val_mae: 0.0800
# Epoch 18/50
# 228/228 [==============================] - 4s 19ms/step - loss: 9.3391e-04 - mae: 0.0217 - val_loss: 0.0118 - val_mae: 0.0793
# Epoch 19/50
# 228/228 [==============================] - 7s 29ms/step - loss: 9.5684e-04 - mae: 0.0225 - val_loss: 0.0149 - val_mae: 0.0831

# %%
results_lstm = evaluate_model(
    lstm_model,
    "LSTM_MODEL1",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm
# Out:
# Evaluation of LSTM_MODEL1:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0021 	 | 	test mae: 0.0394
# Val loss: 0.0108 	 | 	val mae: 0.0817
# Train loss: 0.001 	 | 	train mae: 0.0239
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL1     0.0021    0.0394    0.0108   0.0817       0.001     0.0239

# %%
train_preds = lstm_model.predict(train)
val_preds = lstm_model.predict(val)
test_preds = lstm_model.predict(test)

print(f"Shape of train_preds: {train_preds.shape}")
print(f"Shape of val_preds: {val_preds.shape}")
print(f"Shape of test_preds: {test_preds.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds.ravel(), "val_preds": val_preds.ravel(), "test_preds": test_preds.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Test 2

# %%
# Shared attributes:
loss_function = 'mse'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 20

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model2 = Sequential()
lstm_model2.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model2.add(Dense(1))

lstm_model2.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model2.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 1, 128)            66560
#
#  dense_10 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model2 = lstm_model2.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model2.save('lstm_model2.h5')
# Out:
# Epoch 1/20
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\2986742100.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model2 = lstm_model2.fit_generator(
# 228/228 [==============================] - 6s 19ms/step - loss: 0.0230 - mae: 0.0851 - val_loss: 0.0327 - val_mae: 0.1208
# Epoch 2/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0051 - mae: 0.0373 - val_loss: 0.0220 - val_mae: 0.1024
# Epoch 3/20
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0028 - mae: 0.0316 - val_loss: 0.0135 - val_mae: 0.0882
# Epoch 4/20
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0018 - mae: 0.0276 - val_loss: 0.0125 - val_mae: 0.0826
# Epoch 5/20
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0015 - mae: 0.0270 - val_loss: 0.0113 - val_mae: 0.0824
# Epoch 6/20
# 228/228 [==============================] - 5s 23ms/step - loss: 0.0013 - mae: 0.0247 - val_loss: 0.0132 - val_mae: 0.0808
# Epoch 7/20
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0012 - mae: 0.0241 - val_loss: 0.0116 - val_mae: 0.0800
# Epoch 8/20
# 228/228 [==============================] - 5s 24ms/step - loss: 0.0012 - mae: 0.0243 - val_loss: 0.0141 - val_mae: 0.0822
# Epoch 9/20
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0011 - mae: 0.0237 - val_loss: 0.0160 - val_mae: 0.0877
# Epoch 10/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0113 - val_mae: 0.0803
# Epoch 11/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.7819e-04 - mae: 0.0220 - val_loss: 0.0105 - val_mae: 0.0868
# Epoch 12/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.7275e-04 - mae: 0.0225 - val_loss: 0.0114 - val_mae: 0.0801
# Epoch 13/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.6288e-04 - mae: 0.0220 - val_loss: 0.0106 - val_mae: 0.0831
# Epoch 14/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.4649e-04 - mae: 0.0217 - val_loss: 0.0105 - val_mae: 0.0854
# Epoch 15/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.6818e-04 - mae: 0.0223 - val_loss: 0.0124 - val_mae: 0.0794
# Epoch 16/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.0867e-04 - mae: 0.0212 - val_loss: 0.0119 - val_mae: 0.0810
# Epoch 17/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.0832e-04 - mae: 0.0214 - val_loss: 0.0111 - val_mae: 0.0830
# Epoch 18/20
# 228/228 [==============================] - 4s 18ms/step - loss: 9.6568e-04 - mae: 0.0218 - val_loss: 0.0113 - val_mae: 0.0807
# Epoch 19/20
# 228/228 [==============================] - 4s 18ms/step - loss: 9.0520e-04 - mae: 0.0210 - val_loss: 0.0130 - val_mae: 0.0797
# Epoch 20/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.4700e-04 - mae: 0.0217 - val_loss: 0.0110 - val_mae: 0.0808

# %%
results_lstm2 = evaluate_model(
    lstm_model2,
    "LSTM_MODEL2",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm2
# Out:
# Evaluation of LSTM_MODEL2:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0018 	 | 	test mae: 0.0354
# Val loss: 0.011 	 | 	val mae: 0.0808
# Train loss: 0.0009 	 | 	train mae: 0.0228
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL2     0.0018    0.0354     0.011   0.0808      0.0009     0.0228

# %%
train_preds2 = lstm_model2.predict(train)
val_preds2 = lstm_model2.predict(val)
test_preds2 = lstm_model2.predict(test)

print(f"Shape of train_preds: {train_preds2.shape}")
print(f"Shape of val_preds: {val_preds2.shape}")
print(f"Shape of test_preds: {test_preds2.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds2.ravel(), "val_preds": val_preds2.ravel(), "test_preds": test_preds2.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Test 3

# %%
# Shared attributes:
loss_function = 'mse'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 70

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model3 = Sequential()
lstm_model3.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model3.add(Dense(1))

lstm_model3.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model3.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 1, 128)            66560
#
#  dense_11 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model3 = lstm_model3.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model3.save('lstm_model3.h5')
# Out:
# Epoch 1/70
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\2000003166.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model3 = lstm_model3.fit_generator(
# 228/228 [==============================] - 6s 18ms/step - loss: 0.0218 - mae: 0.0802 - val_loss: 0.0281 - val_mae: 0.1083
# Epoch 2/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0051 - mae: 0.0388 - val_loss: 0.0194 - val_mae: 0.0942
# Epoch 3/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0029 - mae: 0.0318 - val_loss: 0.0153 - val_mae: 0.0874
# Epoch 4/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0018 - mae: 0.0262 - val_loss: 0.0127 - val_mae: 0.0841
# Epoch 5/70
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0015 - mae: 0.0259 - val_loss: 0.0120 - val_mae: 0.0824
# Epoch 6/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0014 - mae: 0.0254 - val_loss: 0.0112 - val_mae: 0.0822
# Epoch 7/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0013 - mae: 0.0248 - val_loss: 0.0125 - val_mae: 0.0803
# Epoch 8/70
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0012 - mae: 0.0244 - val_loss: 0.0119 - val_mae: 0.0798
# Epoch 9/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0012 - mae: 0.0248 - val_loss: 0.0107 - val_mae: 0.0818
# Epoch 10/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0224 - val_loss: 0.0121 - val_mae: 0.0786
# Epoch 11/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0123 - val_mae: 0.0794
# Epoch 12/70
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0011 - mae: 0.0244 - val_loss: 0.0106 - val_mae: 0.0835
# Epoch 13/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0224 - val_loss: 0.0106 - val_mae: 0.0813
# Epoch 14/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0113 - val_mae: 0.0808
# Epoch 15/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.4584e-04 - mae: 0.0220 - val_loss: 0.0125 - val_mae: 0.0796
# Epoch 16/70
# 228/228 [==============================] - 4s 18ms/step - loss: 9.1515e-04 - mae: 0.0218 - val_loss: 0.0132 - val_mae: 0.0800
# Epoch 17/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.8210e-04 - mae: 0.0225 - val_loss: 0.0119 - val_mae: 0.0793
# Epoch 18/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.4435e-04 - mae: 0.0219 - val_loss: 0.0123 - val_mae: 0.0795
# Epoch 19/70
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0010 - mae: 0.0234 - val_loss: 0.0134 - val_mae: 0.0799
# Epoch 20/70
# 228/228 [==============================] - 4s 18ms/step - loss: 9.8426e-04 - mae: 0.0220 - val_loss: 0.0133 - val_mae: 0.0796
# Epoch 21/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.5011e-04 - mae: 0.0221 - val_loss: 0.0152 - val_mae: 0.0841
# Epoch 22/70
# 228/228 [==============================] - 4s 19ms/step - loss: 9.5422e-04 - mae: 0.0217 - val_loss: 0.0107 - val_mae: 0.0865

# %%
results_lstm3 = evaluate_model(
    lstm_model3,
    "LSTM_MODEL3",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm3
# Out:
# Evaluation of LSTM_MODEL3:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
# Test loss: 0.0029 	 | 	test mae: 0.0486
# Val loss: 0.0106 	 | 	val mae: 0.0835
# Train loss: 0.0012 	 | 	train mae: 0.0272
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL3     0.0029    0.0486    0.0106   0.0835      0.0012     0.0272

# %%
train_preds3 = lstm_model3.predict(train)
val_preds3 = lstm_model3.predict(val)
test_preds3 = lstm_model3.predict(test)

print(f"Shape of train_preds: {train_preds3.shape}")
print(f"Shape of val_preds: {val_preds3.shape}")
print(f"Shape of test_preds: {test_preds3.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds3.ravel(), "val_preds": val_preds3.ravel(), "test_preds": test_preds3.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Test 4

# %%
# Shared attributes:
loss_function = 'mae'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 50

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model4 = Sequential()
lstm_model4.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model4.add(Dense(1))

lstm_model4.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model4.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 1, 128)            66560
#
#  dense_12 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model4 = lstm_model4.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model4.save('lstm_model4.h5')
# Out:
# Epoch 1/50
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\308010609.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model4 = lstm_model4.fit_generator(
# 228/228 [==============================] - 7s 24ms/step - loss: 0.0717 - mae: 0.0717 - val_loss: 0.1251 - val_mae: 0.1251
# Epoch 2/50
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0366 - mae: 0.0366 - val_loss: 0.0945 - val_mae: 0.0945
# Epoch 3/50
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0319 - mae: 0.0319 - val_loss: 0.0868 - val_mae: 0.0868
# Epoch 4/50
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0280 - mae: 0.0280 - val_loss: 0.0835 - val_mae: 0.0835
# Epoch 5/50
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0261 - mae: 0.0261 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 6/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0222 - mae: 0.0222 - val_loss: 0.0791 - val_mae: 0.0791
# Epoch 7/50
# 228/228 [==============================] - 5s 23ms/step - loss: 0.0227 - mae: 0.0227 - val_loss: 0.0857 - val_mae: 0.0857
# Epoch 8/50
# 228/228 [==============================] - 6s 28ms/step - loss: 0.0228 - mae: 0.0228 - val_loss: 0.0807 - val_mae: 0.0807
# Epoch 9/50
# 228/228 [==============================] - 6s 27ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0816 - val_mae: 0.0816
# Epoch 10/50
# 228/228 [==============================] - 6s 25ms/step - loss: 0.0221 - mae: 0.0221 - val_loss: 0.0818 - val_mae: 0.0818
# Epoch 11/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 12/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 13/50
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0803 - val_mae: 0.0803
# Epoch 14/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0223 - mae: 0.0223 - val_loss: 0.0798 - val_mae: 0.0798
# Epoch 15/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 16/50
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0212 - mae: 0.0212 - val_loss: 0.0811 - val_mae: 0.0811

# %%
results_lstm4 = evaluate_model(
    lstm_model4,
    "LSTM_MODEL4",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm4
# Out:
# Evaluation of LSTM_MODEL4:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0235 	 | 	test mae: 0.0235
# Val loss: 0.0791 	 | 	val mae: 0.0791
# Train loss: 0.0203 	 | 	train mae: 0.0203
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL4     0.0235    0.0235    0.0791   0.0791      0.0203     0.0203

# %%
train_preds4 = lstm_model4.predict(train)
val_preds4 = lstm_model4.predict(val)
test_preds4 = lstm_model4.predict(test)

print(f"Shape of train_preds: {train_preds4.shape}")
print(f"Shape of val_preds: {val_preds4.shape}")
print(f"Shape of test_preds: {test_preds4.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds4.ravel(), "val_preds": val_preds4.ravel(), "test_preds": test_preds4.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Test 5

# %%
# Shared attributes:
loss_function = 'mae'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 20

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model5 = Sequential()
lstm_model5.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model5.add(Dense(1))

lstm_model5.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model5.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 1, 128)            66560
#
#  dense_13 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model5 = lstm_model5.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model5.save('lstm_model5.h5')
# Out:
# Epoch 1/20
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\2615815181.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model5 = lstm_model5.fit_generator(
# 228/228 [==============================] - 6s 18ms/step - loss: 0.0686 - mae: 0.0686 - val_loss: 0.1075 - val_mae: 0.1075
# Epoch 2/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0362 - mae: 0.0362 - val_loss: 0.0936 - val_mae: 0.0936
# Epoch 3/20
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0314 - mae: 0.0314 - val_loss: 0.0906 - val_mae: 0.0906
# Epoch 4/20
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0262 - mae: 0.0262 - val_loss: 0.0815 - val_mae: 0.0815
# Epoch 5/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0237 - mae: 0.0237 - val_loss: 0.0795 - val_mae: 0.0795
# Epoch 6/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0219 - mae: 0.0219 - val_loss: 0.0826 - val_mae: 0.0826
# Epoch 7/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0260 - mae: 0.0260 - val_loss: 0.0836 - val_mae: 0.0836
# Epoch 8/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0231 - mae: 0.0231 - val_loss: 0.0820 - val_mae: 0.0820
# Epoch 9/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0236 - mae: 0.0236 - val_loss: 0.0804 - val_mae: 0.0804
# Epoch 10/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0221 - mae: 0.0221 - val_loss: 0.0939 - val_mae: 0.0939
# Epoch 11/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0219 - mae: 0.0219 - val_loss: 0.0864 - val_mae: 0.0864
# Epoch 12/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0217 - mae: 0.0217 - val_loss: 0.0815 - val_mae: 0.0815
# Epoch 13/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0233 - mae: 0.0233 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 14/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0207 - mae: 0.0207 - val_loss: 0.0826 - val_mae: 0.0826
# Epoch 15/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0227 - mae: 0.0227 - val_loss: 0.0810 - val_mae: 0.0810

# %%
results_lstm5 = evaluate_model(
    lstm_model5,
    "LSTM_MODEL5",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm5
# Out:
# Evaluation of LSTM_MODEL5:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0239 	 | 	test mae: 0.0239
# Val loss: 0.0795 	 | 	val mae: 0.0795
# Train loss: 0.0207 	 | 	train mae: 0.0207
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL5     0.0239    0.0239    0.0795   0.0795      0.0207     0.0207

# %%
train_preds5 = lstm_model5.predict(train)
val_preds5 = lstm_model5.predict(val)
test_preds5 = lstm_model5.predict(test)

print(f"Shape of train_preds: {train_preds5.shape}")
print(f"Shape of val_preds: {val_preds5.shape}")
print(f"Shape of test_preds: {test_preds5.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 2ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds5.ravel(), "val_preds": val_preds5.ravel(), "test_preds": test_preds5.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Test 6

# %%
# Shared attributes:
loss_function = 'mae'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 70

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model6 = Sequential()
lstm_model6.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model6.add(Dense(1))

lstm_model6.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model6.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 1, 128)            66560
#
#  dense_14 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model6 = lstm_model6.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model6.save('lstm_model6.h5')
# Out:
# Epoch 1/70
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\322467559.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model6 = lstm_model6.fit_generator(
# 228/228 [==============================] - 6s 18ms/step - loss: 0.0730 - mae: 0.0730 - val_loss: 0.1094 - val_mae: 0.1094
# Epoch 2/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0367 - mae: 0.0367 - val_loss: 0.0937 - val_mae: 0.0937
# Epoch 3/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0302 - mae: 0.0302 - val_loss: 0.0887 - val_mae: 0.0887
# Epoch 4/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0315 - mae: 0.0315 - val_loss: 0.0830 - val_mae: 0.0830
# Epoch 5/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0245 - mae: 0.0245 - val_loss: 0.0809 - val_mae: 0.0809
# Epoch 6/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0225 - mae: 0.0225 - val_loss: 0.0799 - val_mae: 0.0799
# Epoch 7/70
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0229 - mae: 0.0229 - val_loss: 0.0812 - val_mae: 0.0812
# Epoch 8/70
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0255 - mae: 0.0255 - val_loss: 0.0815 - val_mae: 0.0815
# Epoch 9/70
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0247 - mae: 0.0247 - val_loss: 0.0797 - val_mae: 0.0797
# Epoch 10/70
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0206 - mae: 0.0206 - val_loss: 0.0906 - val_mae: 0.0906
# Epoch 11/70
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0225 - mae: 0.0225 - val_loss: 0.0821 - val_mae: 0.0821
# Epoch 12/70
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0217 - mae: 0.0217 - val_loss: 0.0790 - val_mae: 0.0790
# Epoch 13/70
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0213 - mae: 0.0213 - val_loss: 0.0795 - val_mae: 0.0795
# Epoch 14/70
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0218 - mae: 0.0218 - val_loss: 0.0802 - val_mae: 0.0802
# Epoch 15/70
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0211 - mae: 0.0211 - val_loss: 0.0935 - val_mae: 0.0935
# Epoch 16/70
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0224 - mae: 0.0224 - val_loss: 0.0815 - val_mae: 0.0815
# Epoch 17/70
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0215 - mae: 0.0215 - val_loss: 0.0863 - val_mae: 0.0863
# Epoch 18/70
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0221 - mae: 0.0221 - val_loss: 0.0796 - val_mae: 0.0796
# Epoch 19/70
# 228/228 [==============================] - 4s 20ms/step - loss: 0.0220 - mae: 0.0220 - val_loss: 0.0809 - val_mae: 0.0809
# Epoch 20/70
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0210 - mae: 0.0210 - val_loss: 0.0815 - val_mae: 0.0815
# Epoch 21/70
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0204 - mae: 0.0204 - val_loss: 0.0805 - val_mae: 0.0805
# Epoch 22/70
# 228/228 [==============================] - 5s 24ms/step - loss: 0.0209 - mae: 0.0209 - val_loss: 0.0885 - val_mae: 0.0885

# %%
results_lstm6 = evaluate_model(
    lstm_model6,
    "LSTM_MODEL6",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm6
# Out:
# Evaluation of LSTM_MODEL6:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
# Test loss: 0.0231 	 | 	test mae: 0.0231
# Val loss: 0.079 	 | 	val mae: 0.079
# Train loss: 0.0202 	 | 	train mae: 0.0202
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL6     0.0231    0.0231     0.079    0.079      0.0202     0.0202

# %%
train_preds6 = lstm_model6.predict(train)
val_preds6 = lstm_model6.predict(val)
test_preds6 = lstm_model6.predict(test)

print(f"Shape of train_preds: {train_preds6.shape}")
print(f"Shape of val_preds: {val_preds6.shape}")
print(f"Shape of test_preds: {test_preds6.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 3ms/step
# 9/9 [==============================] - 0s 2ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds6.ravel(), "val_preds": val_preds6.ravel(), "test_preds": test_preds6.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Test 7

# %%
# Shared attributes:
loss_function = 'mean_squared_error'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 50

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model7 = Sequential()
lstm_model7.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model7.add(Dense(1))

lstm_model7.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model7.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 1, 128)            66560
#
#  dense_15 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model7 = lstm_model7.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model7.save('lstm_model7.h5')
# Out:
# Epoch 1/50
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\3065704124.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model7 = lstm_model7.fit_generator(
# 228/228 [==============================] - 7s 21ms/step - loss: 0.0225 - mae: 0.0789 - val_loss: 0.0281 - val_mae: 0.1087
# Epoch 2/50
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0052 - mae: 0.0383 - val_loss: 0.0197 - val_mae: 0.0950
# Epoch 3/50
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0029 - mae: 0.0314 - val_loss: 0.0143 - val_mae: 0.0875
# Epoch 4/50
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0019 - mae: 0.0273 - val_loss: 0.0154 - val_mae: 0.0868
# Epoch 5/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0017 - mae: 0.0282 - val_loss: 0.0133 - val_mae: 0.0810
# Epoch 6/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0015 - mae: 0.0267 - val_loss: 0.0115 - val_mae: 0.0817
# Epoch 7/50
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0013 - mae: 0.0245 - val_loss: 0.0110 - val_mae: 0.0821
# Epoch 8/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0012 - mae: 0.0234 - val_loss: 0.0124 - val_mae: 0.0798
# Epoch 9/50
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0130 - val_mae: 0.0801
# Epoch 10/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0010 - mae: 0.0223 - val_loss: 0.0116 - val_mae: 0.0802
# Epoch 11/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0131 - val_mae: 0.0803
# Epoch 12/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 0.0117 - val_mae: 0.0807
# Epoch 13/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.9359e-04 - mae: 0.0225 - val_loss: 0.0125 - val_mae: 0.0791
# Epoch 14/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.7933e-04 - mae: 0.0228 - val_loss: 0.0109 - val_mae: 0.0811
# Epoch 15/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.6118e-04 - mae: 0.0223 - val_loss: 0.0133 - val_mae: 0.0802
# Epoch 16/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.6999e-04 - mae: 0.0222 - val_loss: 0.0112 - val_mae: 0.0805
# Epoch 17/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.3911e-04 - mae: 0.0216 - val_loss: 0.0116 - val_mae: 0.0799
# Epoch 18/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.4795e-04 - mae: 0.0216 - val_loss: 0.0125 - val_mae: 0.0798
# Epoch 19/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0011 - mae: 0.0233 - val_loss: 0.0108 - val_mae: 0.0829
# Epoch 20/50
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0113 - val_mae: 0.0800
# Epoch 21/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.2420e-04 - mae: 0.0213 - val_loss: 0.0106 - val_mae: 0.0862
# Epoch 22/50
# 228/228 [==============================] - 5s 21ms/step - loss: 9.2639e-04 - mae: 0.0219 - val_loss: 0.0120 - val_mae: 0.0800
# Epoch 23/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.3847e-04 - mae: 0.0220 - val_loss: 0.0127 - val_mae: 0.0795
# Epoch 24/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.4192e-04 - mae: 0.0218 - val_loss: 0.0111 - val_mae: 0.0820
# Epoch 25/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.5251e-04 - mae: 0.0221 - val_loss: 0.0125 - val_mae: 0.0794
# Epoch 26/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.9044e-04 - mae: 0.0224 - val_loss: 0.0113 - val_mae: 0.0803
# Epoch 27/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.7578e-04 - mae: 0.0221 - val_loss: 0.0111 - val_mae: 0.0816
# Epoch 28/50
# 228/228 [==============================] - 5s 20ms/step - loss: 8.8962e-04 - mae: 0.0206 - val_loss: 0.0112 - val_mae: 0.0806
# Epoch 29/50
# 228/228 [==============================] - 5s 21ms/step - loss: 9.1367e-04 - mae: 0.0213 - val_loss: 0.0122 - val_mae: 0.0785
# Epoch 30/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.3288e-04 - mae: 0.0218 - val_loss: 0.0118 - val_mae: 0.0789
# Epoch 31/50
# 228/228 [==============================] - 5s 20ms/step - loss: 9.5397e-04 - mae: 0.0217 - val_loss: 0.0114 - val_mae: 0.0808

# %%
results_lstm7 = evaluate_model(
    lstm_model7,
    "LSTM_MODEL7",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm7
# Out:
# Evaluation of LSTM_MODEL7:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0045 	 | 	test mae: 0.0619
# Val loss: 0.0106 	 | 	val mae: 0.0862
# Train loss: 0.0015 	 | 	train mae: 0.03
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL7     0.0045    0.0619    0.0106   0.0862      0.0015       0.03

# %%
train_preds7 = lstm_model7.predict(train)
val_preds7 = lstm_model7.predict(val)
test_preds7 = lstm_model7.predict(test)

print(f"Shape of train_preds: {train_preds7.shape}")
print(f"Shape of val_preds: {val_preds7.shape}")
print(f"Shape of test_preds: {test_preds7.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds7.ravel(), "val_preds": val_preds7.ravel(), "test_preds": test_preds7.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Test 8

# %%
# Shared attributes:
loss_function = 'mean_squared_error'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 20

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model8 = Sequential()
lstm_model8.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model8.add(Dense(1))

lstm_model8.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model8.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 1, 128)            66560
#
#  dense_16 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model8 = lstm_model8.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model8.save('lstm_model8.h5')
# Out:
# Epoch 1/20
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1758783459.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model8 = lstm_model8.fit_generator(
# 228/228 [==============================] - 6s 18ms/step - loss: 0.0201 - mae: 0.0784 - val_loss: 0.0266 - val_mae: 0.1054
# Epoch 2/20
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0046 - mae: 0.0361 - val_loss: 0.0192 - val_mae: 0.0940
# Epoch 3/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0025 - mae: 0.0304 - val_loss: 0.0131 - val_mae: 0.0867
# Epoch 4/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0018 - mae: 0.0275 - val_loss: 0.0141 - val_mae: 0.0831
# Epoch 5/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0016 - mae: 0.0274 - val_loss: 0.0153 - val_mae: 0.0858
# Epoch 6/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0013 - mae: 0.0247 - val_loss: 0.0116 - val_mae: 0.0810
# Epoch 7/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0012 - mae: 0.0246 - val_loss: 0.0107 - val_mae: 0.0817
# Epoch 8/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0011 - mae: 0.0231 - val_loss: 0.0110 - val_mae: 0.0822
# Epoch 9/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0011 - mae: 0.0238 - val_loss: 0.0112 - val_mae: 0.0807
# Epoch 10/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0135 - val_mae: 0.0804
# Epoch 11/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0227 - val_loss: 0.0118 - val_mae: 0.0801
# Epoch 12/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0235 - val_loss: 0.0158 - val_mae: 0.0865
# Epoch 13/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.6301e-04 - mae: 0.0221 - val_loss: 0.0132 - val_mae: 0.0799
# Epoch 14/20
# 228/228 [==============================] - 4s 17ms/step - loss: 9.4857e-04 - mae: 0.0223 - val_loss: 0.0123 - val_mae: 0.0791
# Epoch 15/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0133 - val_mae: 0.0801
# Epoch 16/20
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0010 - mae: 0.0235 - val_loss: 0.0109 - val_mae: 0.0828
# Epoch 17/20
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0010 - mae: 0.0225 - val_loss: 0.0136 - val_mae: 0.0802

# %%
results_lstm8 = evaluate_model(
    lstm_model8,
    "LSTM_MODEL8",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm8
# Out:
# Evaluation of LSTM_MODEL8:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0026 	 | 	test mae: 0.0424
# Val loss: 0.0107 	 | 	val mae: 0.0817
# Train loss: 0.0011 	 | 	train mae: 0.0245
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL8     0.0026    0.0424    0.0107   0.0817      0.0011     0.0245

# %%
train_preds8 = lstm_model8.predict(train)
val_preds8 = lstm_model8.predict(val)
test_preds8 = lstm_model8.predict(test)

print(f"Shape of train_preds: {train_preds8.shape}")
print(f"Shape of val_preds: {val_preds8.shape}")
print(f"Shape of test_preds: {test_preds8.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 3ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds8.ravel(), "val_preds": val_preds8.ravel(), "test_preds": test_preds8.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Test 9

# %%
# Shared attributes:
loss_function = 'mean_squared_error'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 70

num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model9 = Sequential()
lstm_model9.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model9.add(Dense(1))

lstm_model9.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model9.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 1, 128)            66560
#
#  dense_17 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model9 = lstm_model9.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model9.save('lstm_model9.h5')
# Out:
# Epoch 1/70
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\3395444151.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model9 = lstm_model9.fit_generator(
# 228/228 [==============================] - 6s 20ms/step - loss: 0.0185 - mae: 0.0727 - val_loss: 0.0338 - val_mae: 0.1292
# Epoch 2/70
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0047 - mae: 0.0380 - val_loss: 0.0178 - val_mae: 0.0923
# Epoch 3/70
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0026 - mae: 0.0305 - val_loss: 0.0141 - val_mae: 0.0858
# Epoch 4/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0018 - mae: 0.0280 - val_loss: 0.0127 - val_mae: 0.0813
# Epoch 5/70
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0014 - mae: 0.0259 - val_loss: 0.0127 - val_mae: 0.0804
# Epoch 6/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0121 - val_mae: 0.0799
# Epoch 7/70
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0011 - mae: 0.0231 - val_loss: 0.0127 - val_mae: 0.0799
# Epoch 8/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0011 - mae: 0.0235 - val_loss: 0.0148 - val_mae: 0.0838
# Epoch 9/70
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0011 - mae: 0.0228 - val_loss: 0.0114 - val_mae: 0.0798
# Epoch 10/70
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0152 - val_mae: 0.0845
# Epoch 11/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0229 - val_loss: 0.0119 - val_mae: 0.0794
# Epoch 12/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.2941e-04 - mae: 0.0212 - val_loss: 0.0122 - val_mae: 0.0796
# Epoch 13/70
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0011 - mae: 0.0239 - val_loss: 0.0108 - val_mae: 0.0821
# Epoch 14/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.8481e-04 - mae: 0.0224 - val_loss: 0.0141 - val_mae: 0.0818
# Epoch 15/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.8764e-04 - mae: 0.0228 - val_loss: 0.0105 - val_mae: 0.0834
# Epoch 16/70
# 228/228 [==============================] - 4s 19ms/step - loss: 9.8649e-04 - mae: 0.0224 - val_loss: 0.0134 - val_mae: 0.0801
# Epoch 17/70
# 228/228 [==============================] - 5s 21ms/step - loss: 9.5093e-04 - mae: 0.0219 - val_loss: 0.0130 - val_mae: 0.0796
# Epoch 18/70
# 228/228 [==============================] - 4s 18ms/step - loss: 9.8322e-04 - mae: 0.0223 - val_loss: 0.0107 - val_mae: 0.0834
# Epoch 19/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0228 - val_loss: 0.0110 - val_mae: 0.0817
# Epoch 20/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.9970e-04 - mae: 0.0230 - val_loss: 0.0150 - val_mae: 0.0833
# Epoch 21/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.5187e-04 - mae: 0.0221 - val_loss: 0.0110 - val_mae: 0.0822
# Epoch 22/70
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0010 - mae: 0.0234 - val_loss: 0.0115 - val_mae: 0.0800
# Epoch 23/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.5297e-04 - mae: 0.0217 - val_loss: 0.0118 - val_mae: 0.0794
# Epoch 24/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.3639e-04 - mae: 0.0216 - val_loss: 0.0115 - val_mae: 0.0807
# Epoch 25/70
# 228/228 [==============================] - 4s 17ms/step - loss: 9.5700e-04 - mae: 0.0222 - val_loss: 0.0118 - val_mae: 0.0800

# %%
results_lstm9 = evaluate_model(
    lstm_model9,
    "LSTM_MODEL9",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm9
# Out:
# Evaluation of LSTM_MODEL9:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# Test loss: 0.0031 	 | 	test mae: 0.0499
# Val loss: 0.0105 	 | 	val mae: 0.0834
# Train loss: 0.0012 	 | 	train mae: 0.0276
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL9     0.0031    0.0499    0.0105   0.0834      0.0012     0.0276

# %%
train_preds9 = lstm_model9.predict(train)
val_preds9 = lstm_model9.predict(val)
test_preds9 = lstm_model9.predict(test)

print(f"Shape of train_preds: {train_preds9.shape}")
print(f"Shape of val_preds: {val_preds9.shape}")
print(f"Shape of test_preds: {test_preds9.shape}")
# Out:
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# 9/9 [==============================] - 0s 1ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds9.ravel(), "val_preds": val_preds9.ravel(), "test_preds": test_preds9.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")

# %% [markdown]
# #### Results

# %%
results_lstm_all = pd.concat([results_lstm,
                             results_lstm2,
                             results_lstm3,
                             results_lstm4,
                             results_lstm5,
                             results_lstm6,
                             results_lstm7,
                             results_lstm8,
                             results_lstm9])
results_lstm_all
# Out:
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0  LSTM_MODEL1     0.0021    0.0394    0.0108   0.0817      0.0010     0.0239
# 0  LSTM_MODEL2     0.0018    0.0354    0.0110   0.0808      0.0009     0.0228
# 0  LSTM_MODEL3     0.0029    0.0486    0.0106   0.0835      0.0012     0.0272
# 0  LSTM_MODEL4     0.0235    0.0235    0.0791   0.0791      0.0203     0.0203
# 0  LSTM_MODEL5     0.0239    0.0239    0.0795   0.0795      0.0207     0.0207
# 0  LSTM_MODEL6     0.0231    0.0231    0.0790   0.0790      0.0202     0.0202
# 0  LSTM_MODEL7     0.0045    0.0619    0.0106   0.0862      0.0015     0.0300
# 0  LSTM_MODEL8     0.0026    0.0424    0.0107   0.0817      0.0011     0.0245
# 0  LSTM_MODEL9     0.0031    0.0499    0.0105   0.0834      0.0012     0.0276

# %% [markdown]
# #### RNN best model vs. LSTM best model

# %%
results = pd.concat([results_rnn2, results_lstm2])
results
# Out:
#     model_name  test_loss  test_mae  val_loss  val_mae  train_loss  train_mae
# 0   RNN_MODEL2     0.0009    0.0226    0.0122   0.0794      0.0008     0.0190
# 0  LSTM_MODEL2     0.0018    0.0354    0.0110   0.0808      0.0009     0.0228

# %%
def plot_models_comparison(model_1_history, model_2_history, model_name_1, model_name_2, metric='mae'):
    val_metric = 'val_' + metric
        
    model_1_train_values = model_1_history.history[metric]
    model_1_val_values = model_1_history.history[val_metric]
    model_2_train_values = model_2_history.history[metric]
    model_2_val_values = model_2_history.history[val_metric]
        
    epochs = range(1, len(model_1_train_values) + 1)
        
    plt.figure(figsize=(10,4))
    plt.plot(epochs, model_1_train_values, color='lightblue', label=f'Training {metric}')
    plt.plot(epochs, model_1_val_values, color='pink', label=f'Validation {metric}')
    
    plt.title(f'{model_name_1} performance')
    plt.legend()
    
    plt.figure(figsize=(10,4))
    plt.plot(epochs, model_2_train_values, color='lightblue', label=f'Training {metric}')
    plt.plot(epochs, model_2_val_values, color='pink', label=f'Validation {metric}')
    
    plt.title(f'{model_name_2} performance')
    plt.legend()

# %% [markdown]
# **Note:** The irregularities in the validation curves can be explained by multiple factors, namely the size of the validation dataset (considerably small when compared to the training dataset, which may have a greater impact on the average mean squared error), as well as the different distribution and trend of the validation data.

# %%
end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {int(total_time//60)} minutes and {int(total_time%60)} seconds")
# Out:
# Total time taken: 25 minutes and 34 seconds

# %% [markdown]
# # Working with the best models: trying the effect of dropout layers

# %%
from tensorflow.keras.layers import Dropout

# %%
def plot_models_comparison(model_1_history, model_2_history, model_name_1, model_name_2, metric='mae'):
    val_metric = 'val_' + metric
        
    model_1_train_values = model_1_history.history[metric]
    model_1_val_values = model_1_history.history[val_metric]
    model_2_train_values = model_2_history.history[metric]
    model_2_val_values = model_2_history.history[val_metric]
        
    epochs = range(1, len(model_1_train_values) + 1)
        
    plt.figure(figsize=(10,4))
    plt.plot(epochs, model_1_train_values, color='lightblue', label=f'Training {metric}')
    plt.plot(epochs, model_1_val_values, color='pink', label=f'Validation {metric}')
    
    plt.title(f'{model_name_1} performance')
    plt.legend()
    
    epochs = range(1, len(model_2_train_values) + 1)

    plt.figure(figsize=(10,4))
    plt.plot(epochs, model_2_train_values, color='lightblue', label=f'Training {metric}')
    plt.plot(epochs, model_2_val_values, color='pink', label=f'Validation {metric}')
    
    plt.title(f'{model_name_2} performance')
    plt.legend()

# %%
plot_models_comparison(history_rnn_model2, history_lstm_model2, "RNN_MODEL2", "LSTM_MODEL2")

# %% [markdown]
# ### RNN

# %%
# Best model attributes (model 2)
loss_function = 'mse'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 20

# %%
num_samples, num_input_features = train.shape
# Define RNN's architecture here:
rnn_model_dropout = Sequential()
rnn_model_dropout.add(SimpleRNN(units=128, input_shape=(num_input_features, 1), return_sequences=True))
rnn_model_dropout.add(Dropout(0.2))
rnn_model_dropout.add(Dense(1))

rnn_model_dropout.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
rnn_model_dropout.summary()

history_rnn_model_dropout = rnn_model_dropout.fit_generator(
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs
)

rnn_model_dropout.save('rnn_model_dropout.h5')
results_rnn_dropout = evaluate_model(
    rnn_model_dropout,
    "RNN_MODEL_DROPOUT",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_rnn_dropout

train_preds_dropout = rnn_model_dropout.predict(train)
val_preds_dropout = rnn_model_dropout.predict(val)
test_preds_dropout = rnn_model_dropout.predict(test)

print(f"Shape of train_preds: {train_preds_dropout.shape}")
print(f"Shape of val_preds: {val_preds_dropout.shape}")
print(f"Shape of test_preds: {test_preds_dropout.shape}")


data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds_dropout.ravel(), "val_preds": val_preds_dropout.ravel(), "test_preds": test_preds_dropout.ravel()
}

datetime_indexes = {
    "train": open_prices[:split_time-validation_split_time].index,
    "train_preds": open_prices[:split_time-validation_split_time].index,
    "val": open_prices[split_time-validation_split_time : split_time].index,
    "val_preds": open_prices[split_time-validation_split_time : split_time].index,
    "test": open_prices[split_time:].index,
    "test_preds": open_prices[split_time:].index
}

plot_predictions(data, datetime_indexes, "RNN Predictions")
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_10 (SimpleRNN)   (None, 1, 128)            16640
#
#  dropout_1 (Dropout)         (None, 1, 128)            0
#
#  dense_19 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 16,769
# Trainable params: 16,769
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\4157078799.py:11: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_rnn_model_dropout = rnn_model_dropout.fit_generator(
# 228/228 [==============================] - 3s 9ms/step - loss: 0.0075 - mae: 0.0561 - val_loss: 0.0120 - val_mae: 0.0810
# Epoch 2/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0024 - mae: 0.0364 - val_loss: 0.0108 - val_mae: 0.0823
# Epoch 3/20
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0024 - mae: 0.0359 - val_loss: 0.0114 - val_mae: 0.0822
# Epoch 4/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0019 - mae: 0.0326 - val_loss: 0.0105 - val_mae: 0.0859
# Epoch 5/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0020 - mae: 0.0329 - val_loss: 0.0153 - val_mae: 0.0841
# Epoch 6/20
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0017 - mae: 0.0301 - val_loss: 0.0153 - val_mae: 0.0843
# Epoch 7/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0019 - mae: 0.0319 - val_loss: 0.0126 - val_mae: 0.0805
# Epoch 8/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0017 - mae: 0.0299 - val_loss: 0.0107 - val_mae: 0.0868
# Epoch 9/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0021 - mae: 0.0333 - val_loss: 0.0117 - val_mae: 0.0898
# Epoch 10/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0017 - mae: 0.0297 - val_loss: 0.0128 - val_mae: 0.0802
# Epoch 11/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0017 - mae: 0.0300 - val_loss: 0.0123 - val_mae: 0.0800
# Epoch 12/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0017 - mae: 0.0302 - val_loss: 0.0126 - val_mae: 0.0805
# Epoch 13/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0016 - mae: 0.0285 - val_loss: 0.0133 - val_mae: 0.0805
# Epoch 14/20
# 228/228 [==============================] - 2s 10ms/step - loss: 0.0016 - mae: 0.0287 - val_loss: 0.0108 - val_mae: 0.0848
# Epoch 15/20
# 228/228 [==============================] - 2s 7ms/step - loss: 0.0019 - mae: 0.0319 - val_loss: 0.0128 - val_mae: 0.0805
# Epoch 16/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0015 - mae: 0.0279 - val_loss: 0.0141 - val_mae: 0.0815
# Epoch 17/20
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0015 - mae: 0.0281 - val_loss: 0.0126 - val_mae: 0.0977
# Epoch 18/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0017 - mae: 0.0295 - val_loss: 0.0143 - val_mae: 0.0819
# Epoch 19/20
# 228/228 [==============================] - 2s 8ms/step - loss: 0.0014 - mae: 0.0273 - val_loss: 0.0137 - val_mae: 0.0810
# Epoch 20/20
# 228/228 [==============================] - 2s 9ms/step - loss: 0.0015 - mae: 0.0284 - val_loss: 0.0126 - val_mae: 0.0816
# Evaluation of RNN_MODEL_DROPOUT:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
# Test loss: 0.0011 	 | 	test mae: 0.0253
# Val loss: 0.0126 	 | 	val mae: 0.0816
# Train loss: 0.0009 	 | 	train mae: 0.0204
# 229/229 [==============================] - 1s 1ms/step
# 3/3 [==============================] - 0s 979us/step
# 9/9 [==============================] - 0s 2ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %%
results_rnn_dropout
# Out:
#           model_name  test_loss  test_mae  val_loss  val_mae  train_loss  \
# 0  RNN_MODEL_DROPOUT     0.0011    0.0253    0.0126   0.0816      0.0009
#
#    train_mae
# 0     0.0204

# %% [markdown]
# ### LSTM

# %%
# Best model attributes (model 2)
loss_function = 'mse'  # other options: rmse, mae
optimizer = 'adam'  # other options: rmsprop, sgd, adagrad, adamax
metrics = ['mae']
epochs = 20


num_samples, num_input_features = train.shape

# %%
# Define LSTM's architecture here:
lstm_model_dropout = Sequential()
lstm_model_dropout.add(LSTM(units=128, input_shape=(num_input_features, 1), return_sequences=True))
lstm_model_dropout.add(Dropout(0.2))
lstm_model_dropout.add(Dense(1))

lstm_model_dropout.compile(loss=loss_function, optimizer=optimizer, metrics=metrics)
lstm_model_dropout.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 1, 128)            66560
#
#  dropout_2 (Dropout)         (None, 1, 128)            0
#
#  dense_20 (Dense)            (None, 1, 1)              129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_lstm_model_dropout = lstm_model_dropout.fit_generator( 
    train_generator, 
    validation_data=val_generator, 
    epochs=epochs,
    callbacks=[early_stopping])

lstm_model_dropout.save('lstm_model_dropout.h5')
# Out:
# Epoch 1/20
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\4096131102.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_lstm_model_dropout = lstm_model_dropout.fit_generator(
# 228/228 [==============================] - 7s 21ms/step - loss: 0.0230 - mae: 0.0876 - val_loss: 0.0321 - val_mae: 0.1167
# Epoch 2/20
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0058 - mae: 0.0455 - val_loss: 0.0235 - val_mae: 0.1072
# Epoch 3/20
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0036 - mae: 0.0397 - val_loss: 0.0151 - val_mae: 0.0870
# Epoch 4/20
# 228/228 [==============================] - 4s 17ms/step - loss: 0.0025 - mae: 0.0346 - val_loss: 0.0114 - val_mae: 0.0869
# Epoch 5/20
# 228/228 [==============================] - 4s 18ms/step - loss: 0.0022 - mae: 0.0335 - val_loss: 0.0111 - val_mae: 0.0857
# Epoch 6/20
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0020 - mae: 0.0328 - val_loss: 0.0140 - val_mae: 0.0822
# Epoch 7/20
# 228/228 [==============================] - 5s 22ms/step - loss: 0.0018 - mae: 0.0311 - val_loss: 0.0141 - val_mae: 0.0820
# Epoch 8/20
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0017 - mae: 0.0301 - val_loss: 0.0142 - val_mae: 0.0821
# Epoch 9/20
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0017 - mae: 0.0302 - val_loss: 0.0114 - val_mae: 0.0799
# Epoch 10/20
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0018 - mae: 0.0310 - val_loss: 0.0141 - val_mae: 0.0817
# Epoch 11/20
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0016 - mae: 0.0293 - val_loss: 0.0154 - val_mae: 0.0853
# Epoch 12/20
# 228/228 [==============================] - 4s 19ms/step - loss: 0.0015 - mae: 0.0283 - val_loss: 0.0104 - val_mae: 0.0859
# Epoch 13/20
# 228/228 [==============================] - 6s 28ms/step - loss: 0.0015 - mae: 0.0283 - val_loss: 0.0111 - val_mae: 0.0804
# Epoch 14/20
# 228/228 [==============================] - 5s 24ms/step - loss: 0.0015 - mae: 0.0286 - val_loss: 0.0131 - val_mae: 0.0798
# Epoch 15/20
# 228/228 [==============================] - 5s 20ms/step - loss: 0.0015 - mae: 0.0278 - val_loss: 0.0106 - val_mae: 0.0829
# Epoch 16/20
# 228/228 [==============================] - 5s 23ms/step - loss: 0.0015 - mae: 0.0286 - val_loss: 0.0137 - val_mae: 0.0805
# Epoch 17/20
# 228/228 [==============================] - 7s 29ms/step - loss: 0.0015 - mae: 0.0280 - val_loss: 0.0107 - val_mae: 0.0826
# Epoch 18/20
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0015 - mae: 0.0281 - val_loss: 0.0107 - val_mae: 0.0840
# Epoch 19/20
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0014 - mae: 0.0268 - val_loss: 0.0116 - val_mae: 0.0804
# Epoch 20/20
# 228/228 [==============================] - 5s 21ms/step - loss: 0.0014 - mae: 0.0267 - val_loss: 0.0136 - val_mae: 0.0801

# %%
results_lstm_model_dropout = evaluate_model(
    lstm_model_dropout,
    "LSTM_MODEL_DROPOUT",
    train_generator,
    val_generator,
    test_generator,
    verbose=True 
)

results_lstm_model_dropout
# Out:
# Evaluation of LSTM_MODEL_DROPOUT:
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:6: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   train_loss, train_mae = model.evaluate_generator(train_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:7: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   val_loss, val_mae = model.evaluate_generator(val_gen)
# C:\Users\Joao\AppData\Local\Temp\ipykernel_22972\1209038209.py:8: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   test_loss, test_mae = model.evaluate_generator(test_gen)
# Test loss: 0.0007 	 | 	test mae: 0.0202
# Val loss: 0.0136 	 | 	val mae: 0.0801
# Train loss: 0.001 	 | 	train mae: 0.0227
#            model_name  test_loss  test_mae  val_loss  val_mae  train_loss  \
# 0  LSTM_MODEL_DROPOUT     0.0007    0.0202    0.0136   0.0801       0.001
#
#    train_mae
# 0     0.0227

# %%
train_preds_dropout = lstm_model_dropout.predict(train)
val_preds_dropout = lstm_model_dropout.predict(val)
test_preds_dropout = lstm_model_dropout.predict(test)

print(f"Shape of train_preds: {train_preds_dropout.shape}")
print(f"Shape of val_preds: {val_preds_dropout.shape}")
print(f"Shape of test_preds: {test_preds_dropout.shape}")
data = {
    "train": train, "val": val, "test": test, 
    "train_preds": train_preds_dropout.ravel(), "val_preds": val_preds_dropout.ravel(), "test_preds": test_preds_dropout.ravel()
}

plot_predictions(data, datetime_indexes, "LSTM Predictions")
# Out:
# 229/229 [==============================] - 1s 2ms/step
# 3/3 [==============================] - 0s 0s/step
# 9/9 [==============================] - 0s 2ms/step
# Shape of train_preds: (7311, 1, 1)
# Shape of val_preds: (90, 1, 1)
# Shape of test_preds: (270, 1, 1)

# %% [markdown]
# ### Without Dropout vs With Dropout

# %%
plot_models_comparison(history_rnn_model2, history_lstm_model2, "RNN_MODEL2", "LSTM_MODEL2")

# %%
plot_models_comparison(history_rnn_model_dropout, history_lstm_model_dropout, "RNN_MODEL_DROPOUT", "LSTM_MODEL_DROPOUT")
